# %%
import pandas as pd
from parsers.indexParser import *
from parsers.dataParser import *
from parsers.senseIndexParser import *

# %%
fileExtensions = ['verb', 'adj', 'noun', 'adv']
indexdfverb = createIndexDF(f'dict/index.verb')
indexdfadj = createIndexDF(f'dict/index.adj')
indexdfnoun = createIndexDF(f'dict/index.noun')
indexdfadv = createIndexDF(f'dict/index.adv')
indexdf = pd.concat([indexdfverb[['lemma', 'pos', 'synset_offset']], indexdfadj[['lemma', 'pos', 'synset_offset']], 
           indexdfnoun[['lemma', 'pos', 'synset_offset']], indexdfadv[['lemma', 'pos', 'synset_offset']]], ignore_index=True)

# %%
lemma_synset_map = {}
synset_lemma_map = {}
lemmas = indexdf['lemma'].to_list()
synsets = indexdf['synset_offset'].to_list()
for lemma, synset in zip(lemmas, synsets):
    for s in synset:
        if lemma not in lemma_synset_map.keys():
            lemma_synset_map[lemma] = []
        if s not in synset_lemma_map.keys():
            synset_lemma_map[s] = []
        lemma_synset_map[lemma].append(s)
        synset_lemma_map[s].append(lemma)

# %%
lemma_synset_map
# Out:
# {'aah': ['00865776'],
#  'abacinate': ['02168378'],
#  'abandon': ['02228031',
#   '02227741',
#   '02076676',
#   '00613393',
#   '00614057',
#   '04885398',
#   '07481223'],
#  'abase': ['01799794'],
#  'abash': ['01792097'],
#  'abate': ['00245289', '00245059'],
#  'abbreviate': ['00243900', '00243749'],
#  'abdicate': ['02379198'],
#  'abduce': ['01015866'],
#  'abduct': ['01471043', '01449427'],
#  'aberrate': ['02662076', '02661769'],
#  'abet': ['02549211'],
#  'abhor': ['01774426'],
#  'abide': ['02637202', '00668099'],
#  'abide_by': ['02542280', '02457233'],
#  'abjure': ['00798717'],
#  'ablactate': ['01186958'],
#  'ablate': ['00275466', '00177578'],
#  'abnegate': ['02213074', '01116275', '00758042'],
#  'abolish': ['02427334'],
#  'abominate': ['01774426'],
#  'abort': ['00353839', '00060063', '00059899', '00034939'],
#  'abound': ['02715279', '02715595'],
#  'abound_in': ['02715923'],
#  'about-face': ['01909042', '00689068', '00346936', '00163406'],
#  'abrade': ['01254013', '01251651'],
#  'abrase': ['01254013'],
#  'abreact': ['01815471'],
#  'abridge': ['00243900', '00236843'],
#  'abrogate': ['02478584'],
#  'abscise': ['01255355', '01255222'],
#  'abscond': ['02073714'],
#  'abseil': ['01923058', '00326809'],
#  'absent': ['00421535', '01847672', '00927832', '00165171'],
#  'absolve': ['00903711', '00902424'],
#  'absorb': ['01539633',
#   '00602255',
#   '02216560',
#   '01539063',
#   '00395698',
#   '02765464',
#   '00601043',
#   '01470524',
#   '00600370'],
#  'absquatulate': ['02073714'],
#  'abstain': ['02463426', '01196037'],
#  'abstract': ['00692329',
#   '02276866',
#   '00734587',
#   '01008288',
#   '00011757',
#   '01980557',
#   '00862526',
#   '05854150',
#   '06468951'],
#  'abuse': ['02516594',
#   '00203213',
#   '00845299',
#   '00203556',
#   '00419908',
#   '06715223',
#   '00947719'],
#  'abut': ['01466978'],
#  'aby': ['02520509'],
#  'abye': ['02520509'],
#  'accede': ['00878348', '02381397', '00804139'],
#  'accelerate': ['00438178', '00439343'],
#  'accent': ['01013367',
#   '00983333',
#   '07131511',
#   '14434866',
#   '07155661',
#   '07085375',
#   '06822198'],
#  'accentuate': ['01013367', '00983333'],
#  'accept': ['00686447',
#   '02236124',
#   '00797697',
#   '00719231',
#   '02236624',
#   '02301825',
#   '00668805',
#   '02741546',
#   '02210622',
#   '02209936',
#   '00718489'],
#  'access': ['02248808',
#   '02007417',
#   '05176188',
#   '05175467',
#   '02671062',
#   '06354204',
#   '02671224',
#   '00281132'],
#  'accession': ['00999568',
#   '13424477',
#   '13341962',
#   '13253423',
#   '07177192',
#   '05176188',
#   '00236581'],
#  'acclaim': ['00861725', '00861929', '06691684'],
#  'acclimate': ['00393677'],
#  'acclimatise': ['00393677'],
#  'acclimatize': ['00393677'],
#  'accommodate': ['02702830',
#   '00299580',
#   '01184453',
#   '02732798',
#   '02651424',
#   '00885925',
#   '00482893'],
#  'accompany': ['02716165', '02025550', '01728355', '02716767'],
#  'accomplish': ['01640855', '02526085'],
#  'accord': ['02700104',
#   '02255268',
#   '13971065',
#   '07176804',
#   '06773434',
#   '04713332'],
#  'accost': ['00990655', '00781652'],
#  'account': ['02607432',
#   '02265231',
#   '00965035',
#   '00867644',
#   '06514093',
#   '06681551',
#   '13929037',
#   '06738281',
#   '09179382',
#   '05169037',
#   '13354985',
#   '07217924',
#   '06516955',
#   '05157732'],
#  'account_for': ['02635033', '00939621'],
#  'accouter': ['02342016'],
#  'accoutre': ['02342016'],
#  'accredit': ['02475535', '02475772', '00727791'],
#  'accrete': ['00396325', '00159368'],
#  'accrue': ['00155869', '02230056'],
#  'acculturate': ['00159880'],
#  'accumulate': ['02304982', '00158804'],
#  'accurse': ['00864910'],
#  'accuse': ['00842989', '00843468'],
#  'accustom': ['00273445'],
#  'ace': ['02522581',
#   '01113367',
#   '01085130',
#   '01077759',
#   '02341864',
#   '13742573',
#   '02673291',
#   '09762509',
#   '14735642',
#   '08175498',
#   '00568701'],
#  'acerbate': ['01773535', '00270440'],
#  'acetify': ['02196690', '00264875'],
#  'acetylate': ['00524299', '00524083'],
#  'acetylise': ['00524299', '00524083'],
#  'acetylize': ['00524299', '00524083'],
#  'ache': ['02121511', '01805684', '02122164', '14323683'],
#  'achieve': ['02526085'],
#  'achromatise': ['00524530'],
#  'achromatize': ['00524530'],
#  'acid-wash': ['01537271'],
#  'acidify': ['02196690', '00264875'],
#  'acidulate': ['02196690'],
#  'acknowledge': ['00817311',
#   '00892698',
#   '01059123',
#   '00892467',
#   '00740449',
#   '00592883'],
#  'acquaint': ['00901103', '00874175', '00832778'],
#  'acquiesce': ['00804139'],
#  'acquire': ['02210855',
#   '00524682',
#   '00094460',
#   '02695378',
#   '02288295',
#   '00597915',
#   '00545557'],
#  'acquit': ['00904046', '02518161'],
#  'act': ['02367363',
#   '00010435',
#   '01719302',
#   '01095899',
#   '00013615',
#   '02744977',
#   '02525447',
#   '02419073',
#   '01721556',
#   '01719921',
#   '06532095',
#   '00030358',
#   '07009640',
#   '06892016',
#   '07014029'],
#  'act_as': ['02671613', '00013615'],
#  'act_involuntarily': ['00010241'],
#  'act_on': ['02376429', '02376631'],
#  'act_out': ['01722645', '01722447'],
#  'act_reflexively': ['00010241'],
#  'act_superior': ['02593551'],
#  'act_up': ['02517655', '02122522'],
#  'act_upon': ['02536557'],
#  'action': ['02582042',
#   '01640855',
#   '00037396',
#   '14006945',
#   '00952963',
#   '13518963',
#   '06373513',
#   '04835950',
#   '02677718',
#   '01181902',
#   '01182312',
#   '00576451'],
#  'activate': ['01643657', '00190682', '00191385', '00190999', '00190886'],
#  'actualise': ['01644746', '00987870'],
#  'actualize': ['01644746', '00987870'],
#  'actuate': ['01643657', '01649999'],
#  'acuminate': ['00393227', '02167285'],
#  'ad-lib': ['01728840', '01845451', '02213557', '06714697'],
#  'adapt': ['00299580', '00150287'],
#  'add': ['00182406',
#   '01027174',
#   '02324478',
#   '00640828',
#   '00949288',
#   '02745172',
#   '14056280'],
#  'add_on': ['00183757', '01328705'],
#  'add_to': ['00157347'],
#  'add_together': ['00949288', '00640828'],
#  'add_up': ['02627363', '00949288', '02645007', '02619612'],
#  'addict': ['01165290', '09769076', '09768830'],
#  'addle': ['00620532', '00210647'],
#  'address': ['00897564',
#   '00989201',
#   '00990812',
#   '01150981',
#   '01160899',
#   '02601456',
#   '02249018',
#   '01033527',
#   '00990655',
#   '00464687',
#   '06356515',
#   '08491027',
#   '07238694',
#   '07067591',
#   '06794216',
#   '06787150',
#   '05082648',
#   '04842232'],
#  'adduce': ['01015866'],
#  'adduct': ['01449236', '14584016'],
#  'adhere': ['02718178',
#   '00486557',
#   '01220885',
#   '02638845',
#   '02638630',
#   '01356750'],
#  'adjoin': ['01466978', '01205696', '00183383'],
#  'adjourn': ['00364297', '02428487'],
#  'adjudge': ['00822367'],
#  'adjudicate': ['02501278', '00698855'],
#  'adjure': ['00759657', '00755331'],
#  'adjust': ['00296178', '00464321', '00150287', '00298067', '00699334'],
#  'admeasure': ['02295082'],
#  'administer': ['02431971', '02309621', '02294436', '00081072', '02603567'],
#  'administrate': ['02431971'],
#  'admire': ['01827858', '02164694'],
#  'admit': ['00817311',
#   '02502536',
#   '02449847',
#   '02236624',
#   '02745486',
#   '02741682',
#   '02732798',
#   '02671279'],
#  'admix': ['00396703'],
#  'admonish': ['00870577', '00871195', '00824066'],
#  'adolesce': ['00252710'],
#  'adopt': ['02346895',
#   '02346724',
#   '02381726',
#   '00524682',
#   '00413195',
#   '01701311',
#   '00601822'],
#  'adore': ['01777817'],
#  'adorn': ['01675963', '02748927', '02386675'],
#  'adsorb': ['01540232'],
#  'adulate': ['00880518'],
#  'adulterate': ['00487748', '01908539'],
#  'adumbrate': ['01006421', '00927711'],
#  'advance': ['01992503',
#   '00875806',
#   '00497061',
#   '02554922',
#   '01993926',
#   '01111028',
#   '00248659',
#   '00558371',
#   '02397637',
#   '02283949',
#   '01994288',
#   '00158222',
#   '00813915',
#   '00198383',
#   '07445265',
#   '07357388',
#   '07164349',
#   '00282050',
#   '13375891',
#   '00364260'],
#  'advantage': ['02513268', '05155821', '13610426', '05142863'],
#  'advect': ['02102655'],
#  'adventure': ['02544348', '02545272', '00796315'],
#  'advert': ['02170427', '01026728', '01024190', '07248801'],
#  'advertise': ['00975902', '00976653'],
#  'advertize': ['00976653', '00975902'],
#  'advise': ['00872886', '00873682', '00875394'],
#  'advocate': ['00875141', '00827730', '09774783', '09775663'],
#  'aerate': ['02112891', '00190999', '00185465'],
#  'aerify': ['00442267'],
#  'aerosolise': ['01377940', '01377758'],
#  'aerosolize': ['01377758', '01377940'],
#  'aestivate': ['00016183'],
#  'affect': ['00137313',
#   '00019448',
#   '02677097',
#   '00838043',
#   '01767949',
#   '07479926'],
#  'affiance': ['00886602'],
#  'affiliate': ['02589245', '02435311', '09776346', '08009478'],
#  'affirm': ['00665886', '01011031', '01011725'],
#  'affix': ['01356370', '01328705', '01298283', '06308049'],
#  'afflict': ['01797730', '00259927'],
#  'afford': ['01192628', '02339171', '02744451', '02358034'],
#  'afforest': ['01567888'],
#  'affranchise': ['02477135'],
#  'affright': ['01779165', '07520612'],
#  'affront': ['00848420', '01225027'],
#  'age': ['00248512',
#   '00248026',
#   '00249679',
#   '04924103',
#   '15254028',
#   '15145171',
#   '15242955',
#   '15153787'],
#  'agenise': ['00517365'],
#  'agenize': ['00517365'],
#  'agglomerate': ['01484714', '00467019', '14711647', '07961480'],
#  'agglutinate': ['01222016', '01221684', '00053154'],
#  'aggrade': ['01307771'],
#  'aggrandise': ['00956405'],
#  'aggrandize': ['00956405'],
#  'aggravate': ['00208210', '01820901'],
#  'aggregate': ['02627555',
#   '01385170',
#   '00467240',
#   '02216694',
#   '04353803',
#   '14594925',
#   '08418103'],
#  'aggress': ['01118449'],
#  'aggrieve': ['02513879', '01797582'],
#  'aggroup': ['01089878'],
#  'agitate': ['02585050',
#   '01762528',
#   '02589576',
#   '01893988',
#   '01889610',
#   '01419473'],
#  'agnise': ['00728617'],
#  'agnize': ['00728617'],
#  'agonise': ['01794523', '01794363'],
#  'agonize': ['01794523', '01794363'],
#  'agree': ['00805376',
#   '00764222',
#   '02657219',
#   '02700104',
#   '02741793',
#   '02291135',
#   '01035530'],
#  'aid': ['02547586',
#   '00082081',
#   '05154908',
#   '01207609',
#   '13265904',
#   '00654885'],
#  'ail': ['00078665', '00070816', '07818277'],
#  'aim': ['01151110',
#   '00708980',
#   '01026975',
#   '00713015',
#   '01150559',
#   '00955472',
#   '00705517',
#   '05982152',
#   '05981230',
#   '00815644',
#   '08680888'],
#  'air': ['02112891',
#   '00973728',
#   '00973056',
#   '00954608',
#   '00489029',
#   '00488770',
#   '14841267',
#   '08653314',
#   '04727214',
#   '11431754',
#   '08499057',
#   '14842703',
#   '07028373',
#   '06255354',
#   '00300441'],
#  'air-condition': ['02331575', '02331326'],
#  'air-cool': ['02331326'],
#  'air-drop': ['01489859'],
#  'air-freight': ['01951159'],
#  'air-ship': ['01951159'],
#  'air-slake': ['00214794'],
#  'air_out': ['02112891', '00488770'],
#  'airbrush': ['01363320', '02685995'],
#  'airfreight': ['01951159'],
#  'airlift': ['01452057', '00316594'],
#  'airmail': ['01032127', '06622993', '06264812'],
#  'airt': ['01953334'],
#  'alarm': ['01782650',
#   '00872414',
#   '07519773',
#   '02694426',
#   '06803157',
#   '02694662'],
#  'alchemise': ['00139586'],
#  'alchemize': ['00139586'],
#  'alcoholise': ['00139908', '00139729'],
#  'alcoholize': ['01176734', '00139908', '00139729'],
#  'alert': ['00872414',
#   '00091311',
#   '00874226',
#   '00190653',
#   '14031660',
#   '07224774',
#   '06803157'],
#  'alibi': ['00893741', '06741099', '06741305'],
#  'alien': ['02221010',
#   '01823528',
#   '01349927',
#   '01035007',
#   '10103485',
#   '10661002',
#   '09484465'],
#  'alienate': ['01823528', '02221010', '01823888'],
#  'alight': ['01978700', '01978576', '00475308'],
#  'align': ['00464321', '02658867', '00733632', '00466053'],
#  'aliment': ['01204191', '07570720'],
#  'aline': ['00464321'],
#  'alkalify': ['00265094'],
#  'alkalinise': ['00134898', '00134737'],
#  'alkalinize': ['00134898', '00134737'],
#  'alkalise': ['00265094'],
#  'alkalize': ['00265094'],
#  'allay': ['01815185', '01204021'],
#  'allege': ['01016002'],
#  'allegorise': ['00624263', '00135285'],
#  'allegorize': ['00624263', '00135285'],
#  'alleviate': ['00064095', '00518395'],
#  'alligator': ['00337700', '14760447', '01698434'],
#  'alliterate': ['01702154'],
#  'allocate': ['02234087'],
#  'allot': ['02228698', '02255268', '02294436'],
#  'allow': ['02423183',
#   '00802318',
#   '02255462',
#   '00724150',
#   '02721438',
#   '00723545',
#   '02745486',
#   '02423650',
#   '02319669',
#   '00802946'],
#  'allow_for': ['02721438'],
#  'allow_in': ['02502536'],
#  'allowance': ['02255821',
#   '13286254',
#   '13293377',
#   '13274092',
#   '04749991',
#   '13370215',
#   '01141841'],
#  'alloy': ['00493517', '00396880', '14586769', '14487598'],
#  'allude': ['01026728'],
#  'allure': ['00793785', '04688842'],
#  'ally': ['02430191', '08305942', '09785042'],
#  'ally_with': ['02434737'],
#  'alphabetise': ['00279239'],
#  'alphabetize': ['00279239', '02330967'],
#  'alter': ['00126264', '00123170', '01667132', '00201407', '00060477'],
#  'altercate': ['00775156'],
#  'alternate': ['00121506',
#   '02393726',
#   '00604930',
#   '00121678',
#   '00121214',
#   '00676093',
#   '01853934',
#   '00675928',
#   '01663359',
#   '10680153'],
#  'aluminise': ['01338113'],
#  'aluminize': ['01338113'],
#  'amalgamate': ['01462005', '02476637'],
#  'amass': ['00158804', '02304982'],
#  'amaze': ['00724832', '00622384'],
#  'ambition': ['01826060', '07484547', '04836268'],
#  'amble': ['01918183', '00284101'],
#  'ambulate': ['01911698'],
#  'ambuscade': ['01138204', '01246926'],
#  'ambush': ['01138204', '01142203', '01246926'],
#  'ameliorate': ['00205885', '00205046'],
#  'amend': ['00996328', '00205885', '00199912'],
#  'amerce': ['02500265', '02498987'],
#  'americanise': ['00410406', '00409643'],
#  'americanize': ['00410406', '00409643'],
#  'ammoniate': ['00187147'],
#  'ammonify': ['00497219'],
#  'amnesty': ['00905677', '14529082', '06552639', '01249315'],
#  'amortise': ['02352263'],
#  'amortize': ['02352263'],
#  'amount': ['02664992',
#   '02645007',
#   '02627363',
#   '13331198',
#   '05107765',
#   '00033615',
#   '05861067'],
#  'amplify': ['00434077', '00839834', '00264386', '00263904'],
#  'amputate': ['01254692'],
#  'amuse': ['02492362', '00859758'],
#  'anaesthetise': ['00021065'],
#  'anaesthetize': ['00021065'],
#  'anagram': ['00625518', '06287620'],
#  'anagrammatise': ['00625518'],
#  'anagrammatize': ['00625518'],
#  'analogise': ['00653283'],
#  'analogize': ['00653283'],
#  'analyse': ['00644583', '00736216', '00643473', '00643197'],
#  'analyze': ['00644583', '00643473', '00736216', '00643197'],
#  'anastomose': ['01292366', '01292169'],
#  'anathematise': ['00864910'],
#  'anathematize': ['00864910'],
#  'anathemise': ['00865958', '00864910'],
#  'anathemize': ['00865958', '00864910'],
#  'anatomise': ['01550594'],
#  'anatomize': ['01550594', '00645241'],
#  'anchor': ['01304944', '01304716', '02709367', '05694232', '09792969'],
#  'ancylose': ['00096396', '00096264'],
#  'anele': ['00085626'],
#  'anesthetise': ['00021065'],
#  'anesthetize': ['00021065'],
#  'anger': ['01785971', '01787106', '07516354', '14036539', '00758972'],
#  'angle': ['02044866',
#   '02038357',
#   '01319346',
#   '01141612',
#   '00680485',
#   '13887509',
#   '06211078',
#   '09702673'],
#  'angle-park': ['01934731'],
#  'anglicise': ['00300317'],
#  'anglicize': ['00300317'],
#  'anguish': ['01794969', '01792567', '07496755', '14449022'],
#  'angulate': ['00573457', '02047807'],
#  'animadvert': ['01027668', '00827158'],
#  'animalise': ['01680756', '00114052', '00113853'],
#  'animalize': ['01680756', '00114052', '00113853'],
#  'animate': ['01812720',
#   '00547995',
#   '00192836',
#   '00024279',
#   '00120252',
#   '00118066',
#   '00117385'],
#  'animise': ['00547995'],
#  'animize': ['00547995'],
#  'ankylose': ['00096396', '00096264'],
#  'anneal': ['00303056'],
#  'annex': ['02215355', '01329141', '02713594'],
#  'annihilate': ['00470701'],
#  'annotate': ['01704953', '00961329'],
#  'announce': ['00974367', '00965871', '00975427', '00974173'],
#  'annoy': ['01787955'],
#  'annul': ['02478059', '00799798'],
#  'annunciate': ['00974173'],
#  'anodise': ['00136567'],
#  'anodize': ['00136567'],
#  'anoint': ['00675412', '00085626'],
#  'answer': ['00815686',
#   '00719590',
#   '00636279',
#   '00635523',
#   '00815171',
#   '02746017',
#   '02669789',
#   '02658570',
#   '01183896',
#   '00718308',
#   '06746005',
#   '06743506',
#   '07200527',
#   '06560254',
#   '01234952'],
#  'answer_for': ['00867644'],
#  'antagonise': ['02564841', '01807314'],
#  'antagonize': ['01807314', '02564841'],
#  'ante': ['01139380', '13343917'],
#  'ante_up': ['02252931'],
#  'antecede': ['02712443'],
#  'antedate': ['02712443', '00277086'],
#  'anthologise': ['01626705'],
#  'anthologize': ['01626705'],
#  'anthropomorphise': ['00727409'],
#  'anthropomorphize': ['00727409'],
#  'antic': ['00105778', '00967646', '00427580'],
#  'anticipate': ['00719734',
#   '02565491',
#   '00720808',
#   '00917772',
#   '01804961',
#   '00342640'],
#  'antiquate': ['00253664', '00253501'],
#  'antique': ['02326795',
#   '00253501',
#   '01639446',
#   '00974159',
#   '01638962',
#   '10376890',
#   '02723754'],
#  'antisepticize': ['00062774'],
#  'ape': ['02675067', '00849592', '02470325', '09964411', '09796185'],
#  'aphorise': ['00741911'],
#  'aphorize': ['00741911'],
#  'apologise': ['00894738', '00892923'],
#  'apologize': ['00892923', '00894738'],
#  'apostatise': ['00757856'],
#  'apostatize': ['00757856'],
#  'apostrophise': ['00993754'],
#  'apostrophize': ['00993754'],
#  'apotheose': ['00693633'],
#  'apotheosise': ['00693633'],
#  'apotheosize': ['00693633'],
#  'appal': ['01810447', '01782650'],
#  'appall': ['01810447', '01782650'],
#  'apparel': ['00047945', '02728440'],
#  'appeal': ['02497586',
#   '00755447',
#   '01807882',
#   '02497824',
#   '01024864',
#   '07186828',
#   '04687333',
#   '01185611',
#   '06513764'],
#  'appear': ['02133435',
#   '00422090',
#   '00425967',
#   '02134672',
#   '00425071',
#   '01721169',
#   '02597762'],
#  'appease': ['01765392', '01194114', '00765213'],
#  'append': ['01328705', '01328513', '01027174'],
#  'apperceive': ['02107097'],
#  'appertain': ['02653706'],
#  'applaud': ['00861929', '00860292'],
#  'applique': ['01670777', '02730437'],
#  'apply': ['01158872',
#   '02676789',
#   '00765396',
#   '01363648',
#   '02707429',
#   '02309165',
#   '02561332',
#   '02560164',
#   '01026558',
#   '02595523'],
#  'appoint': ['02396205', '02475922', '02341370'],
#  'apportion': ['02234087', '02294179'],
#  'appose': ['01500214'],
#  'appraise': ['00681429', '00646542'],
#  'appreciate': ['01805982', '00592341', '02256109', '00316195', '00315605'],
#  'apprehend': ['00588221', '01215137', '01782432'],
#  'apprentice': ['00602635', '09801864'],
#  'apprise': ['00873682', '00831074', '00316195', '00315605'],
#  'apprize': ['00873682', '00831074', '00316195', '00315605'],
#  'approach': ['02053941',
#   '02703952',
#   '02439281',
#   '01849746',
#   '00990392',
#   '00941140',
#   '00280853',
#   '02671062',
#   '08493961',
#   '07310507',
#   '07164349',
#   '05046471',
#   '04746134',
#   '00573268'],
#  'approbate': ['00803815', '00687033'],
#  'appropriate': ['00724150', '02272549', '00134701'],
#  'approve': ['00806502', '00673983'],
#  'approximate': ['02666060', '00672433', '00915976', '00451872', '00448130'],
#  'aquaplane': ['01956512', '01942854', '02731900'],
#  'aquatint': ['01750668', '02732295', '00939091'],
#  'arbitrage': ['02260959', '01093965'],
#  'arbitrate': ['00760956'],
#  'arborise': ['00329495'],
#  'arborize': ['00329495'],
#  'arc': ['02034986', '11511523', '13874384', '13896100'],
#  'arch': ['02034986',
#   '02338917',
#   '02226661',
#   '02122715',
#   '13886133',
#   '05576573',
#   '02734217',
#   '02733524'],
#  'arch_over': ['02035315'],
#  'archaise': ['00522068'],
#  'archaize': ['00522068'],
#  'archive': ['01384638', '02735086'],
#  'argue': ['00772189', '00773432', '00772640'],
#  'argufy': ['00775156'],
#  'arise': ['02624263',
#   '02625786',
#   '01983264',
#   '00339738',
#   '01968569',
#   '02583139',
#   '00018158'],
#  'arm': ['01087197',
#   '02334867',
#   '05563770',
#   '02737833',
#   '04565375',
#   '02737660',
#   '08401248',
#   '04236377'],
#  'armor': ['02341684', '02739668', '08197742', '01902750'],
#  'armour': ['02341684', '08197742', '02739668', '01902750'],
#  'aromatise': ['02126382'],
#  'aromatize': ['02126382'],
#  'arouse': ['01759326',
#   '00018526',
#   '01629958',
#   '00022686',
#   '00018813',
#   '01894164',
#   '01762283'],
#  'arraign': ['02497992', '00843852'],
#  'arrange': ['01463963',
#   '01021629',
#   '01648126',
#   '01745141',
#   '00038849',
#   '01706129',
#   '00735571'],
#  'array': ['01474209',
#   '00733632',
#   '07939382',
#   '06888174',
#   '02742322',
#   '02742194'],
#  'arrest': ['01215137',
#   '01131473',
#   '01505958',
#   '01859586',
#   '00088725',
#   '14010927'],
#  'arrive': ['02005948', '02585860'],
#  'arrive_at': ['02020590'],
#  'arrogate': ['02275365', '02276746', '02274482'],
#  'arse_about': ['02639606'],
#  'arse_around': ['02639606', '00854150'],
#  'arterialise': ['00120095'],
#  'arterialize': ['00120095'],
#  'article': ['00885082', '06268096', '00022903', '06392935', '06324669'],
#  'articulate': ['02354287',
#   '00980453',
#   '00978549',
#   '02622637',
#   '00978369',
#   '00150202',
#   '00153410'],
#  'ascend': ['01969216',
#   '02751451',
#   '02381571',
#   '02105657',
#   '02103021',
#   '02037472',
#   '01970348',
#   '01969779'],
#  'ascertain': ['00918872', '00662589', '00920336', '00721302'],
#  'ascribe': ['00726300'],
#  'ash': ['00383437', '14769160', '12303462', '12303921'],
#  'ask': ['00784342',
#   '00752493',
#   '00784727',
#   '00755745',
#   '00897746',
#   '02627934',
#   '01068565'],
#  'ask_for': ['01760143'],
#  'ask_for_it': ['00351048'],
#  'ask_for_trouble': ['00351048'],
#  'ask_in': ['01469770'],
#  'ask_out': ['02486693'],
#  'ask_over': ['02384686'],
#  'ask_round': ['02384686'],
#  'asperse': ['00846509'],
#  'asphalt': ['01267866', '14769465', '14667455'],
#  'asphyxiate': ['01569181', '01476180', '00359511'],
#  'aspirate': ['01540693', '00952039', '00003316', '07116758'],
#  'aspire': ['00705517'],
#  'assail': ['01120069', '01119169', '00862683'],
#  'assassinate': ['02483000', '00847158'],
#  'assault': ['01120069',
#   '02567519',
#   '00862683',
#   '00974444',
#   '00767826',
#   '02384225',
#   '00773402'],
#  'assay': ['00694974',
#   '02530167',
#   '05738625',
#   '14584390',
#   '07219162',
#   '00791527'],
#  'assemble': ['01656788', '02428924', '02598143'],
#  'assent': ['00804139', '07175575'],
#  'assert': ['01016778', '01011031', '02373785', '00717045'],
#  'assert_oneself': ['02519055'],
#  'assess': ['00681429', '02308552', '02308389', '00682230'],
#  'asseverate': ['01016778'],
#  'assibilate': ['01054027', '00547022'],
#  'assign': ['02391803',
#   '02228698',
#   '00726300',
#   '00677683',
#   '01160370',
#   '02276746',
#   '02228531',
#   '00740053'],
#  'assimilate': ['00602255', '00159642', '00160261', '01540042', '00160447'],
#  'assist': ['02547586', '02414710', '02540670', '01207609', '00558008'],
#  'associate': ['00713167',
#   '02589245',
#   '02470175',
#   '00793426',
#   '09816771',
#   '09945905',
#   '09817174',
#   '07284848',
#   '06697703'],
#  'assoil': ['00904046'],
#  'assonate': ['02750642'],
#  'assort': ['02589245', '00654625'],
#  'assuage': ['01765392', '01204021', '00064095'],
#  'assume': ['00632236',
#   '02381726',
#   '00524682',
#   '02301825',
#   '01982395',
#   '02274482',
#   '01721754',
#   '01470856',
#   '00050652'],
#  'assure': ['00890590',
#   '01019643',
#   '00776268',
#   '00662589',
#   '01766407',
#   '00884011'],
#  'asterisk': ['00510869', '06828389'],
#  'astonish': ['00724832'],
#  'astound': ['00724832'],
#  'astringe': ['01388386', '00304662'],
#  'astrogate': ['01933766', '01841947'],
#  'atom-bomb': ['01132980'],
#  'atomise': ['01373138', '01133288', '00330144'],
#  'atomize': ['01373138', '01133288', '00330144'],
#  'atone': ['02520509', '01796800'],
#  'atrophy': ['00093979', '14365741', '07427060'],
#  'attach': ['01296462', '01290255', '01290422', '02538086', '02273293'],
#  'attach_to': ['02716165', '02705535'],
#  'attack': ['01119169',
#   '00862683',
#   '01118449',
#   '01120069',
#   '00347610',
#   '00019792',
#   '00972621',
#   '00457723',
#   '06711159',
#   '00941140',
#   '00773814',
#   '00236953',
#   '14081375',
#   '13435548',
#   '01220619'],
#  'attain': ['02526085', '02006834', '02286687', '02020590'],
#  'attaint': ['02547225', '02149501'],
#  'attemper': ['00170381'],
#  'attempt': ['02530167', '01651293', '00786195', '00773814'],
#  'attend': ['02612762', '02549581', '02716567', '02540670', '02170427'],
#  'attend_to': ['00616670', '02540670'],
#  'attenuate': ['00226379', '00220701', '00882166'],
#  'attest': ['00820976', '00820352', '01014821', '00820611'],
#  'attire': ['00044149', '02756098'],
#  'attitudinise': ['02519494'],
#  'attitudinize': ['02519494'],
#  'attorn': ['00593200'],
#  'attract': ['01505254', '01807882', '01350025'],
#  'attribute': ['00726300', '00740053', '05849040', '00024264'],
#  'attune': ['00297780'],
#  'auction': ['02244773', '00491161', '00092366'],
#  'auction_off': ['02244773'],
#  'auctioneer': ['02244773', '09608377'],
#  'audit': ['00697062', '00600235', '13411157', '00141176'],
#  'audition': ['01718535', '05657718', '00794614'],
#  'augment': ['00154388', '00157950'],
#  'augur': ['00871942', '00918471', '09823287'],
#  'aurify': ['00382410', '00285231'],
#  'auscultate': ['02150192'],
#  'auspicate': ['00871942', '00347420'],
#  'authenticate': ['00664276'],
#  'author': ['01704452', '10794014', '10126177'],
#  'authorise': ['02473981', '00803325'],
#  'authorize': ['00803325', '02473981'],
#  'autoclave': ['00062973', '02758960'],
#  'autograph': ['00997133', '06407094', '06404907'],
#  'automate': ['00479932'],
#  'automatise': ['00480221', '00479932'],
#  'automatize': ['00480221', '00479932'],
#  'automobile': ['01930738', '02958343'],
#  'autopsy': ['02150039', '00141396'],
#  'autotomise': ['01513990'],
#  'autotomize': ['01513990'],
#  'avail': ['01161561', '02549048', '01193569', '05149832'],
#  'avalanche': ['01966706', '07405137', '07285036'],
#  'avenge': ['01153486'],
#  'aver': ['01016002', '01011031'],
#  'average': ['02645389',
#   '02527294',
#   '00639998',
#   '01594146',
#   '00486290',
#   '01673061',
#   '01531957',
#   '01594811',
#   '01594472',
#   '06021761',
#   '13820655',
#   '05856979'],
#  'average_out': ['00639998', '02645389'],
#  'avert': ['02453321', '02034511'],
#  'avianise': ['00124074'],
#  'avianize': ['00124074'],
#  'aviate': ['01941093'],
#  'avoid': ['00811375', '02453321', '02463510', '01189823', '02478059'],
#  'avouch': ['00819923'],
#  'avow': ['01011031', '00819923'],
#  'avulse': ['02032117'],
#  'await': ['00720063'],
#  'awake': ['00018526', '00186616', '00190653'],
#  'awaken': ['00018813', '00018526', '00736095'],
#  'award': ['02261888', '02262278', '00087663', '06696483', '13268146'],
#  'awe': ['01779644', '07510184', '07521039'],
#  'ax': ['01257953', '00354317', '02764044'],
#  'axe': ['01257953', '00354317', '02764044'],
#  'azure': ['00284958', '00370267', '04969242'],
#  'baa': ['01048330', '07376168'],
#  'babbitt': ['01272349', '14772007'],
#  'babble': ['01065630', '01037650', '02187922', '00937208', '06610143'],
#  'babble_out': ['00937208'],
#  'baby': ['02570267',
#   '09827683',
#   '09827519',
#   '09918554',
#   '09828216',
#   '09827363',
#   '01322221',
#   '00796767'],
#  'baby-sit': ['02602898', '02456270'],
#  'bach': ['02616118', '10830229', '07277915'],
#  'bachelor': ['02616118', '09829923', '10238749'],
#  'back': ['02453889',
#   '01997119',
#   '02556817',
#   '01997512',
#   '02217695',
#   '02693965',
#   '01139104',
#   '00560628',
#   '00223109',
#   '00185857',
#   '00197576',
#   '00131692',
#   '00668816',
#   '05558717',
#   '04059701',
#   '08625846',
#   '09830194',
#   '05588174',
#   '02840619',
#   '02767665',
#   '02767433',
#   '00725775',
#   '00075161',
#   '00074407',
#   '00075269',
#   '00074201',
#   '00075367',
#   '00074964'],
#  'back_away': ['00799383'],
#  'back_down': ['01997680', '02380980'],
#  'back_off': ['01997680', '02380980'],
#  'back_out': ['01997376', '00799383'],
#  'back_up': ['02556126', '01997680', '00223109', '01694620', '01478603'],
#  'backbite': ['00907657'],
#  'backcross': ['01429825'],
#  'backdate': ['02561846'],
#  'backfire': ['02378950',
#   '02173663',
#   '00379023',
#   '07408965',
#   '07408621',
#   '07303153',
#   '00073032'],
#  'background': ['00513492',
#   '04921417',
#   '05933834',
#   '05823517',
#   '07430480',
#   '07285191',
#   '14513259',
#   '02769075',
#   '02768864'],
#  'backhand': ['01404664', '01033840', '02284892', '00566690'],
#  'backlash': ['02378950', '07350192', '00203020'],
#  'backlog': ['00159236', '07953603', '15100945', '13368052'],
#  'backpack': ['01926031', '02769748'],
#  'backpedal': ['01935953', '01929041', '00688960'],
#  'backscatter': ['00330751'],
#  'backslap': ['02374572'],
#  'backslide': ['00204585'],
#  'backspace': ['01005373', '02771004'],
#  'backstitch': ['01330567', '02771383'],
#  'backstop': ['01076130', '09901143', '02771547', '00177638'],
#  'backstroke': ['01962375', '00571283'],
#  'backtrack': ['02004528'],
#  'bacterise': ['00138360'],
#  'bacterize': ['00138360'],
#  'badge': ['01589869', '06882561', '05851131'],
#  'badger': ['01803380', '00767530', '09746536', '02447366'],
#  'badmouth': ['00848169'],
#  'baffle': ['00622384', '02558172', '00234988', '02772868'],
#  'bag': ['01479874',
#   '02717362',
#   '02714360',
#   '02292432',
#   '01485839',
#   '02773037',
#   '13754778',
#   '02797881',
#   '02774152',
#   '13764639',
#   '02773838',
#   '09832321',
#   '02370360',
#   '00432881'],
#  'bail': ['02421749',
#   '02293732',
#   '00890403',
#   '00177136',
#   '00177011',
#   '13350976',
#   '05903445'],
#  'bail_out': ['02494259', '00449426'],
#  'bait': ['00850501', '02577877', '01114911', '05695232', '02776205'],
#  'bake': ['00319886', '01663749', '00544136', '02755565'],
#  'balance': ['02673134',
#   '02264967',
#   '01602318',
#   '02743020',
#   '14002279',
#   '13408980',
#   '05076827',
#   '13897996',
#   '13810818',
#   '13409160',
#   '09753065',
#   '08687150',
#   '05064827',
#   '03118539',
#   '02777402',
#   '02777100'],
#  'bald': ['00126143', '01705088', '00210848', '01698610'],
#  'bale': ['01386200', '02778456', '09032483'],
#  'bale_out': ['00449426'],
#  'balk': ['02583545', '08516080', '05689249', '04045644', '00107279'],
#  'balkanise': ['02469711'],
#  'balkanize': ['02469711'],
#  'ball': ['01523270',
#   '02778669',
#   '03802228',
#   '13899404',
#   '08253268',
#   '05524615',
#   '02779435',
#   '10832731',
#   '07961016',
#   '07448885',
#   '05576194',
#   '00474568',
#   '00107400'],
#  'ball_over': ['01809064'],
#  'ball_up': ['02527651'],
#  'ballast': ['00271403',
#   '02779845',
#   '14699209',
#   '04691992',
#   '02780121',
#   '02779971'],
#  'balloon': ['01948659', '00256117', '02782093', '02782329'],
#  'ballot': ['02463141', '06470922', '00183505'],
#  'ballyhoo': ['00976365', '07248507'],
#  'ballyrag': ['01781520'],
#  'bamboozle': ['00839194'],
#  'ban': ['02493666',
#   '00796392',
#   '02504280',
#   '02504017',
#   '06542047',
#   '13702315',
#   '13685578',
#   '07255401',
#   '06698902'],
#  'band': ['01304342',
#   '01297401',
#   '08240169',
#   '08249038',
#   '04680465',
#   '02784732',
#   '08249960',
#   '06260518',
#   '02784218',
#   '05267211',
#   '04092609',
#   '02785570',
#   '02785365',
#   '02785191',
#   '02784998'],
#  'band_oneself': ['02430078'],
#  'band_together': ['02470685'],
#  'bandage': ['01303547', '00083124', '02785648'],
#  'bandy': ['01147296', '01138446', '00813651', '01018530'],
#  'bandy_about': ['00970107'],
#  'bang': ['01242391',
#   '02187693',
#   '01242832',
#   '02100176',
#   '01426397',
#   '01236941',
#   '07410207',
#   '07376257',
#   '05258985',
#   '07528470',
#   '00064504',
#   '00277585'],
#  'bang_out': ['01728213'],
#  'bang_up': ['01566705', '00053159'],
#  'banish': ['02504017', '02504280', '02503803', '02003359'],
#  'bank': ['02039413',
#   '01587705',
#   '02343374',
#   '02343252',
#   '02343056',
#   '02310855',
#   '01234793',
#   '00688377',
#   '09213565',
#   '08420278',
#   '09213434',
#   '08462066',
#   '13368318',
#   '13356402',
#   '09213828',
#   '04139859',
#   '02787772',
#   '00169305'],
#  'bankroll': ['02216384', '13356569'],
#  'bankrupt': ['02318165', '02026629', '09838370'],
#  'banquet': ['01186208', '01185981', '08253640', '07578093'],
#  'banter': ['00855295', '06777794'],
#  'baptise': ['01028079'],
#  'baptize': ['01028079'],
#  'bar': ['00796588',
#   '01478002',
#   '02503803',
#   '01342910',
#   '02796995',
#   '02789487',
#   '02788689',
#   '06864725',
#   '02789271',
#   '01077350',
#   '13711855',
#   '09214060',
#   '08112402',
#   '04683136',
#   '02937469',
#   '02907391',
#   '02790154',
#   '02790012',
#   '02789770'],
#  'bar_hop': ['01171941'],
#  'bar_mitzvah': ['02474958', '07453924'],
#  'barb': ['01339181', '06767922', '02790550', '02790322', '01898185'],
#  'barbarise': ['00134564', '00134328'],
#  'barbarize': ['00134564', '00134328'],
#  'barbecue': ['00324806', '07654148', '07576781', '02790669'],
#  'barbeque': ['00324806', '07654148', '07576781', '02790669'],
#  'barber': ['00042792', '10834439', '09838895'],
#  'bard': ['01670315', '09839022', '02792305'],
#  'barde': ['01670315'],
#  'bare': ['01340028',
#   '00954608',
#   '00194912',
#   '00457998',
#   '00106821',
#   '02155524',
#   '01698400',
#   '02563466',
#   '01792573',
#   '01714157',
#   '01242750',
#   '01086915',
#   '00060605'],
#  'barf': ['00076400', '14855992'],
#  'bargain': ['02259829', '00764782', '06771159', '13253751'],
#  'bargain_down': ['02259387'],
#  'barge': ['01996574', '01950502', '02792552'],
#  'barge_in': ['02019011', '00780191'],
#  'bark': ['01047596',
#   '01263904',
#   '01263784',
#   '01047745',
#   '00511763',
#   '13162297',
#   '07376731',
#   '02793199',
#   '07376621'],
#  'barnstorm': ['01094898', '01094661'],
#  'baronetise': ['02398681'],
#  'baronetize': ['02398681'],
#  'barrack': ['02651745', '00858781', '00850192', '02794779'],
#  'barrage': ['00863579', '07083441', '00987863'],
#  'barrage_jam': ['01057342'],
#  'barrel': ['01502540',
#   '02795528',
#   '02795169',
#   '13901211',
#   '13764764',
#   '13619920'],
#  'barricade': ['01478002', '01127215', '01127075', '04096848', '02796412'],
#  'barricado': ['01127075'],
#  'barter': ['02259241', '01109687'],
#  'barter_away': ['02294056'],
#  'base': ['00636888',
#   '02756196',
#   '01200068',
#   '01856066',
#   '01592857',
#   '02345859',
#   '02036077',
#   '01589650',
#   '01407816',
#   '01117362',
#   '02798290',
#   '03387016',
#   '02797881',
#   '09215315',
#   '08511777',
#   '06658118',
#   '05793554',
#   '02797692',
#   '14964590',
#   '14618253',
#   '13897837',
#   '13809769',
#   '13597794',
#   '08490402',
#   '08013845',
#   '06300193',
#   '03569964',
#   '02798769',
#   '02798574',
#   '02798117'],
#  'bash': ['01397088', '07410207', '07448038'],
#  'basify': ['00265094'],
#  'bask': ['01820302', '01548181'],
#  'basset': ['00425845', '02088238'],
#  'bastardise': ['02580853', '00818253'],
#  'bastardize': ['02580853', '00818253'],
#  'baste': ['00321652', '01417416', '01331348', '02805111'],
#  'bastinado': ['01399921', '02805845', '00422114'],
#  'bat': ['01413173',
#   '00008195',
#   '01413561',
#   '01413436',
#   '01412912',
#   '02139199',
#   '00458456',
#   '04292414',
#   '03132076',
#   '02806379'],
#  'bat_mitzvah': ['02475109', '07454196'],
#  'batch': ['01386073', '08400772', '13774404', '08400452'],
#  'bate': ['02511075', '02094057', '00216801'],
#  'batfowl': ['01480025'],
#  'bath': ['00037919',
#   '02806530',
#   '00257770',
#   '02808440',
#   '13616560',
#   '08878202',
#   '02807731'],
#  'bathe': ['00035603', '01582070', '00037919', '00442437'],
#  'batik': ['00288814', '02809105'],
#  'batten': ['01306425', '01306292', '02810930', '02810008'],
#  'batten_down': ['01306425'],
#  'batter': ['01417705', '01417416', '00546609', '09843956', '07860805'],
#  'battle': ['01092366', '00953559', '00788973', '00958896'],
#  'baulk': ['02583545', '08516080', '05689249', '04045644'],
#  'bawl': ['01048569', '01046480', '00066862'],
#  'bawl_out': ['00824767'],
#  'bay': ['01048073',
#   '01047951',
#   '00395977',
#   '09215664',
#   '07376836',
#   '11704093',
#   '02812785',
#   '02812631',
#   '02696048',
#   '02388917'],
#  'bayonet': ['01231980', '02812949'],
#  'be': ['02604760',
#   '02616386',
#   '02655135',
#   '02603699',
#   '02749904',
#   '02664769',
#   '02620587',
#   '02445925',
#   '02697725',
#   '02268246',
#   '02614181',
#   '02744820',
#   '02702508',
#   '14631295'],
#  'be_active': ['00014549'],
#  'be_adrift': ['01902783'],
#  'be_after': ['00705227'],
#  'be_amiss': ['00619869'],
#  'be_at_pains': ['02531088'],
#  'be_born': ['00360932'],
#  'be_due': ['02634567'],
#  'be_full': ['01188342'],
#  'be_given': ['02719399'],
#  'be_intimate': ['01426397'],
#  'be_on': ['00424337'],
#  'be_on_cloud_nine': ['01813668'],
#  'be_on_the_ball': ['00596484'],
#  'be_quiet': ['01041061'],
#  'be_sick': ['00076400'],
#  'be_well': ['00065495'],
#  'be_with_it': ['00596484'],
#  'beach': ['01978947', '09217230'],
#  'beacon': ['02160433', '01933204', '07264213', '04041930', '02814860'],
#  'bead': ['02625521',
#   '01670511',
#   '01360091',
#   '02815071',
#   '13901585',
#   '02815237'],
#  'beak': ['01243474', '01758510', '01758308', '12875594', '05598707'],
#  'beam': ['00029214',
#   '02763740',
#   '01067380',
#   '00973056',
#   '02161530',
#   '01829747',
#   '06792645',
#   '02815950',
#   '11428379',
#   '11428023',
#   '05136546',
#   '02816381',
#   '02777292'],
#  'bean': ['01400856', '07724943', '13136316', '12556307', '05539454'],
#  'bear': ['02630871',
#   '00056930',
#   '00668099',
#   '01432601',
#   '01652139',
#   '02301825',
#   '02700867',
#   '02291708',
#   '00047745',
#   '02518161',
#   '02302220',
#   '01601234',
#   '00059019',
#   '02131653',
#   '09845191'],
#  'bear_away': ['01434278'],
#  'bear_down': ['01597096',
#   '01389186',
#   '01121719',
#   '01082023',
#   '00840980',
#   '00750979'],
#  'bear_down_on': ['01927992', '01597096'],
#  'bear_down_upon': ['01927992'],
#  'bear_in_mind': ['00609506'],
#  'bear_off': ['01434278'],
#  'bear_on': ['02676054', '00137313', '00765977', '02679899'],
#  'bear_out': ['02663340'],
#  'bear_up': ['00669243'],
#  'bear_upon': ['00137313'],
#  'bear_witness': ['01015244', '01014821'],
#  'beard': ['02687730',
#   '05261566',
#   '13090594',
#   '09845401',
#   '02416270',
#   '01955318'],
#  'beat': ['01101913',
#   '01397210',
#   '01398919',
#   '01880113',
#   '01624897',
#   '02174830',
#   '02162815',
#   '02093610',
#   '01945938',
#   '01418179',
#   '01399576',
#   '02746140',
#   '02573853',
#   '02175578',
#   '02093390',
#   '01880673',
#   '01879579',
#   '01756006',
#   '01726879',
#   '01399450',
#   '01104852',
#   '00622384',
#   '00075421',
#   '02432154',
#   '08507381',
#   '07400906',
#   '07086518',
#   '11477710',
#   '09845849',
#   '07376937',
#   '07094093',
#   '05058893',
#   '00547616',
#   '00314094'],
#  'beat_a_retreat': ['02009347'],
#  'beat_about': ['00649362'],
#  'beat_around_the_bush': ['00835506'],
#  'beat_back': ['01506157'],
#  'beat_down': ['02259387', '02160321', '01883550'],
#  'beat_in': ['00606471'],
#  'beat_out': ['01101913', '01880560'],
#  'beat_up': ['01397210', '01385643'],
#  'beatify': ['01812324', '01812068', '00822912'],
#  'beautify': ['00293141', '02748927', '01675963'],
#  'beaver': ['02414913',
#   '14764617',
#   '09745229',
#   '05262120',
#   '03237416',
#   '02818254',
#   '02818135',
#   '02363005'],
#  'beaver_away': ['02414913'],
#  'bebop': ['01895263', '07063101'],
#  'becalm': ['00416571'],
#  'bechance': ['00345000', '00344643'],
#  'becharm': ['02586458', '01806505'],
#  'beckon': ['01041415', '01807051', '01041644'],
#  'becloud': ['02157731'],
#  'become': ['00149583', '02626604', '02623529', '02724258'],
#  'become_flat': ['00538323'],
#  'bed': ['02337066',
#   '01567653',
#   '01500082',
#   '01426397',
#   '00017865',
#   '02818832',
#   '02819474',
#   '09217638',
#   '09217867',
#   '08659076',
#   '03650173',
#   '02819881',
#   '02819697'],
#  'bed-hop': ['02095390'],
#  'bed_down': ['00017531'],
#  'bedamn': ['00865958'],
#  'bedaub': ['01251828'],
#  'bedaze': ['02115430'],
#  'bedazzle': ['02162434'],
#  'bedeck': ['01679980'],
#  'bedevil': ['01803003', '00621734'],
#  'bedew': ['00215254'],
#  'bedhop': ['02095390'],
#  'bedight': ['01679980'],
#  'bedim': ['00313860', '00313712'],
#  'bedizen': ['01679254', '00045240'],
#  'bedraggle': ['00216692'],
#  'beef': ['00910973', '02404186', '07663592', '07209965'],
#  'beef_up': ['00220869'],
#  'beep': ['02183175', '00791372', '07377082'],
#  'beeswax': ['01268870', '15094824'],
#  'beetle': ['02697435',
#   '02103612',
#   '01399821',
#   '01353516',
#   '02164464',
#   '03715386'],
#  'beetle_off': ['02011040'],
#  'befall': ['00345000', '00344643'],
#  'befit': ['02699941'],
#  'befog': ['02157731'],
#  'befool': ['02576349', '00854904'],
#  'befoul': ['00492410'],
#  'befriend': ['02588677'],
#  'befuddle': ['00621734', '01190741'],
#  'beg': ['00759269', '00782057', '02270815', '00810226'],
#  'beg_off': ['00894221'],
#  'beget': ['00054628'],
#  'beggar': ['02707681', '02317970', '09847010'],
#  'begild': ['01683101'],
#  'begin': ['00345761',
#   '02608347',
#   '00348746',
#   '00747640',
#   '02679227',
#   '02609203',
#   '02608823',
#   '02600948',
#   '02526509',
#   '01070777',
#   '10841657'],
#  'begrime': ['01534147'],
#  'begrudge': ['01827064', '01825125'],
#  'beguile': ['02578235', '01806505'],
#  'behave': ['00010435', '02518161', '02519666'],
#  'behead': ['01571354'],
#  'behold': ['02130160'],
#  'behoove': ['02668378'],
#  'behove': ['02668378'],
#  'bejewel': ['01678685'],
#  'belabor': ['02415265', '00827302', '01398235'],
#  'belabour': ['02415265', '01398235', '00827302'],
#  'belay': ['01342755', '01342636', '09218494'],
#  'belch': ['00003431', '00307568', '00117578'],
#  'beleaguer': ['01803380', '01127411'],
#  'belie': ['02663141', '00836705'],
#  'believe': ['00683280', '00689344', '00721098', '00684273', '00684068'],
#  'believe_in': ['00733895'],
#  'belittle': ['00864475', '00845909', '00441881'],
#  'bell': ['01297274',
#   '02824448',
#   '03222516',
#   '07377244',
#   '15227593',
#   '13886260',
#   '10842575',
#   '10842376',
#   '10842213',
#   '03017168',
#   '02824858'],
#  'bell_the_cat': ['02545939'],
#  'bellow': ['01048569', '01048718', '07121361', '10843228'],
#  'belly': ['00257535',
#   '05556943',
#   '05555917',
#   '13895262',
#   '08588486',
#   '02157415'],
#  'belly-flop': ['01963316'],
#  'belly-land': ['01980617'],
#  'belly_dance': ['01710190', '00530554'],
#  'belly_out': ['00257535'],
#  'bellyache': ['00910973', '14327266'],
#  'bellylaugh': ['00029742'],
#  'belong': ['02301680',
#   '02737724',
#   '02737876',
#   '02737569',
#   '02756359',
#   '02719930'],
#  'belong_to': ['02719930'],
#  'belt': ['01704030',
#   '01415162',
#   '01366061',
#   '02827883',
#   '02827606',
#   '08509786',
#   '07410207',
#   '09452653',
#   '02828115',
#   '00133338'],
#  'belt_along': ['02058994'],
#  'belt_down': ['01202374'],
#  'belt_out': ['01704030'],
#  'belt_up': ['01041061'],
#  'bemire': ['01534147'],
#  'bemoan': ['00911350'],
#  'bemock': ['00849080'],
#  'bemuse': ['01791232'],
#  'bench': ['02482889',
#   '02141722',
#   '02828884',
#   '09456207',
#   '08166187',
#   '04600486',
#   '08328700',
#   '08209519',
#   '02829116'],
#  'bend': ['02035919',
#   '02033137',
#   '01280014',
#   '02062632',
#   '02034300',
#   '01280488',
#   '13869327',
#   '07310991',
#   '02829696',
#   '13907415',
#   '09133364',
#   '02830013'],
#  'bend_over_backwards': ['00011361'],
#  'benday': ['01750061'],
#  'benefact': ['02548219'],
#  'benefice': ['02201521', '13248087'],
#  'beneficiate': ['00577170'],
#  'benefit': ['02290461', '02290956', '13296899', '05142641', '06892534'],
#  'benficiate': ['00238255'],
#  'benight': ['01809884', '01380483', '00313860'],
#  'benumb': ['02115273'],
#  'beplaster': ['01612964'],
#  'bequeath': ['02229055'],
#  'berate': ['00824767'],
#  'bereave': ['02315421'],
#  'berry': ['01384102', '07742704', '13137409', '10849083'],
#  'berth': ['02336947',
#   '01305542',
#   '01305361',
#   '00586262',
#   '08640111',
#   '02831724'],
#  'beseech': ['00759657'],
#  'beseem': ['02699941'],
#  'beset': ['01789514', '01126700', '01517355'],
#  'beshrew': ['00865958'],
#  'besiege': ['01127411', '01798287', '00778122'],
#  'besmear': ['01251828'],
#  'besmirch': ['00846509', '01252601'],
#  'besot': ['02115618'],
#  'bespangle': ['01669906', '01377444'],
#  'bespatter': ['01538629'],
#  'bespeak': ['00921300', '00752764'],
#  'bespeckle': ['01538310'],
#  'bespot': ['01273529'],
#  'besprinkle': ['00228655'],
#  'best': ['01109259',
#   '00227507',
#   '00067379',
#   '00127531',
#   '09851165',
#   '10850049',
#   '00188137',
#   '00188057',
#   '00509846'],
#  'bestialise': ['00410244'],
#  'bestialize': ['00410244'],
#  'bestir': ['02083806'],
#  'bestir_oneself': ['00348541'],
#  'bestow': ['02263346', '02263692', '02324478'],
#  'bestrew': ['01378331'],
#  'bestride': ['01923414'],
#  'bet': ['00918580', '01155687', '00712708', '13343526', '00506658'],
#  'bet_on': ['01139104'],
#  'betake_oneself': ['01839963'],
#  'bethink': ['02166761', '00683127'],
#  'betide': ['00345000'],
#  'betoken': ['00921300', '00871942'],
#  'betray': ['00936330',
#   '02537407',
#   '01799235',
#   '02576503',
#   '00841986',
#   '00854420'],
#  'betroth': ['00886602'],
#  'better': ['01106864',
#   '00205885',
#   '00205046',
#   '00230335',
#   '00231761',
#   '00067379',
#   '01471260',
#   '05143558',
#   '09851876',
#   '09851719',
#   '05143690',
#   '00059607',
#   '00509846'],
#  'bevel': ['01583993', '02833576', '02833403'],
#  'bewail': ['00911350'],
#  'beware': ['00724664'],
#  'bewhisker': ['02332173'],
#  'bewilder': ['00622384', '01791232'],
#  'bewitch': ['01806505', '00777522', '00776988'],
#  'bewray': ['00936330'],
#  'bias': ['01085677', '00680346', '01719393', '06201908', '13904164'],
#  'bib': ['01172114', '02834397', '02834295'],
#  'bicker': ['00774056', '07184735'],
#  'bicycle': ['01935476', '02834778'],
#  'bid': ['02298632',
#   '00902932',
#   '00759657',
#   '02300060',
#   '02240674',
#   '00793580',
#   '07168131',
#   '00786887',
#   '07165086',
#   '06737112'],
#  'bide': ['02637202'],
#  'biff': ['01416020', '00134780'],
#  'bifurcate': ['02718863', '00329817', '02479602'],
#  'bight': ['01342536', '13875884', '13869896', '09220239', '02837567'],
#  'bike': ['01935476', '03790512', '02834778'],
#  'bilge': ['00258528', '00257947', '15059797', '02838014'],
#  'bilk': ['02572792', '02558172', '02313801', '02074377'],
#  'bill': ['02320374',
#   '00977153',
#   '00991900',
#   '06536853',
#   '06516955',
#   '13393762',
#   '00551407',
#   '07250339',
#   '06793426',
#   '06486874',
#   '02838958',
#   '02838728',
#   '01758308'],
#  'billet': ['02653159', '06626286', '02839200', '00586262'],
#  'billow': ['02041422', '02041728', '02041206', '00256117', '07348545'],
#  'bin': ['01493142', '02839910', '13765306', '06425534'],
#  'bind': ['01356750',
#   '02538086',
#   '01303242',
#   '01303547',
#   '01286913',
#   '00885217',
#   '01335804',
#   '01285440',
#   '00567291',
#   '00074558',
#   '05689801'],
#  'bind_off': ['01286038'],
#  'bind_over': ['02495592'],
#  'binge': ['01193099', '01073824', '00510723'],
#  'bioassay': ['00695120', '05740300'],
#  'biodegrade': ['00191220'],
#  'birch': ['01411978', '02575834', '12281600', '12281241', '02842809'],
#  'bird': ['01139865',
#   '01503061',
#   '07644382',
#   '09989045',
#   '07123870',
#   '04212282'],
#  'bird-nest': ['01383245'],
#  'birdie': ['01598507', '13595276', '04212282'],
#  'birdlime': ['02083237', '14702703'],
#  'birdnest': ['01383245', '09221571'],
#  'birdwatch': ['01139865'],
#  'birl': ['02048272', '02048051'],
#  'birle': ['02048272'],
#  'birr': ['02188587', '13664396', '07399917'],
#  'birth': ['00056930',
#   '15142167',
#   '07320302',
#   '13532886',
#   '13813765',
#   '09856671'],
#  'bisect': ['01550817'],
#  'bitch': ['00910973',
#   '00907657',
#   '14408519',
#   '09982873',
#   '07209965',
#   '02083672'],
#  'bite': ['01445932',
#   '02120451',
#   '01441382',
#   '01445407',
#   '14287408',
#   '07579076',
#   '14297870',
#   '07577374',
#   '07477413',
#   '06776986',
#   '04992834',
#   '00838816',
#   '00361041'],
#  'bite_off': ['01445756'],
#  'bite_out': ['00985706'],
#  'bitt': ['01286554', '02864593'],
#  'bitter': ['02195751',
#   '00116744',
#   '02435901',
#   '01802165',
#   '01364993',
#   '01245610',
#   '02396098',
#   '01711910',
#   '07889814',
#   '05717115',
#   '04994824',
#   '00422435'],
#  'bituminise': ['00517240'],
#  'bituminize': ['00517240'],
#  'bivouac': ['02653996', '02944826', '08518171'],
#  'blab': ['00937208', '01036804'],
#  'blab_out': ['00937208'],
#  'blabber': ['01036804', '10206173'],
#  'black': ['00280532',
#   '00392812',
#   '00241952',
#   '00114797',
#   '01229561',
#   '01131935',
#   '01050088',
#   '00396296',
#   '00274068',
#   '02079507',
#   '01706341',
#   '01402580',
#   '01227546',
#   '00756897',
#   '00421002',
#   '04960277',
#   '13983807',
#   '10852130',
#   '10851987',
#   '09636339',
#   '02846260',
#   '02846141'],
#  'black_market': ['02242256', '08425173', '01097739'],
#  'black_marketeer': ['02246166', '09858560'],
#  'black_out': ['02762299', '00312648', '00201906', '00023868'],
#  'blackball': ['02504017', '02473431', '00207622'],
#  'blackberry': ['01383089', '07744811', '12653762'],
#  'blacken': ['00280532', '00379440'],
#  'blacken_out': ['00312648'],
#  'blackguard': ['00851933', '00845299', '09886220'],
#  'blackjack': ['02581073', '12274863', '02847461', '02847009', '00490350'],
#  'blacklead': ['01602821'],
#  'blackleg': ['02412939', '10554455'],
#  'blacklist': ['02473143', '06487260'],
#  'blackmail': ['02581073', '02241767', '00784598'],
#  'blacktop': ['01266604', '14976871'],
#  'blackwash': ['00847365', '00281703', '06719974', '02847942', '02847852'],
#  'blame': ['00842538',
#   '00842772',
#   '00727991',
#   '00669942',
#   '07237758',
#   '06713752'],
#  'blanch': ['00103619', '00322559'],
#  'blandish': ['00880227'],
#  'blank': ['02451261',
#   '01087093',
#   '00500889',
#   '01425056',
#   '06839190',
#   '03632189',
#   '02849051',
#   '02848921'],
#  'blank_out': ['00609100', '00202089'],
#  'blanket': ['01359007',
#   '02749405',
#   '00526062',
#   '02849154',
#   '09223725',
#   '02849419'],
#  'blanket_jam': ['01057837'],
#  'blare': ['02182479', '02183175', '07377473'],
#  'blare_out': ['00975334'],
#  'blarney': ['00768778', '06696025'],
#  'blaspheme': ['00865387', '00814458'],
#  'blast': ['02182479',
#   '01401772',
#   '01135922',
#   '02101216',
#   '01759021',
#   '01758276',
#   '01134781',
#   '00823827',
#   '00336158',
#   '00241924',
#   '00128867',
#   '07376257',
#   '11465017',
#   '07408171',
#   '07287288',
#   '06711159'],
#  'blast_off': ['01515056'],
#  'blat': ['01048330'],
#  'blat_out': ['00975334'],
#  'blate': ['01048330', '00204249'],
#  'blather': ['01037650', '06610332'],
#  'blaze': ['02764614',
#   '01135086',
#   '02764438',
#   '02014863',
#   '00922025',
#   '13439088',
#   '07305907',
#   '00736786',
#   '04952570',
#   '04681058'],
#  'blaze_away': ['01713587', '01135086', '00767918'],
#  'blaze_out': ['02014863'],
#  'blaze_up': ['02762806'],
#  'blazon': ['01684180', '03058726'],
#  'blazon_out': ['00974786'],
#  'bleach': ['00279822', '00279465', '04961136', '14779205', '00274009'],
#  'bleach_out': ['00279822'],
#  'blear': ['00312990', '02432562'],
#  'bleat': ['01048492', '01048330', '07377931'],
#  'bleed': ['00074834', '00086077', '02360003', '02060792', '00449153'],
#  'bleep': ['02187171', '07377082'],
#  'blemish': ['01549905', '01538161', '00263044', '04692157'],
#  'blench': ['00103619'],
#  'blend': ['01462468',
#   '02700455',
#   '00394813',
#   '07375405',
#   '06288527',
#   '00380696'],
#  'blend_in': ['02700455', '00396035'],
#  'bless': ['00866505', '02264075', '00867231', '00866702'],
#  'blether': ['01037650', '07137129'],
#  'blight': ['02771320', '14562854', '14215331'],
#  'blind': ['02168555',
#   '02168194',
#   '00312278',
#   '02158826',
#   '01746292',
#   '01926654',
#   '07944408',
#   '02851384',
#   '02851099',
#   '06760508'],
#  'blindfold': ['01337927', '02159364', '02851939'],
#  'blindside': ['02596730', '01120612'],
#  'blink': ['00007739', '00008435', '02159890', '00117959'],
#  'blink_away': ['00008435'],
#  'blinker': ['01337819', '02852173', '07262704', '04593629'],
#  'blister': ['00379774',
#   '00863906',
#   '00379996',
#   '14464512',
#   '13088858',
#   '05517837'],
#  'blither': ['01037650'],
#  'blitz': ['01126219', '00976085', '00975781'],
#  'blitzkrieg': ['01093365', '00975781'],
#  'bloat': ['00361797', '00361952', '14315549'],
#  'blob': ['01531998', '13910019'],
#  'block': ['01478002',
#   '02557199',
#   '02559752',
#   '01057034',
#   '02444297',
#   '02198423',
#   '02145543',
#   '01531492',
#   '01479333',
#   '01476483',
#   '01217924',
#   '01147060',
#   '00609100',
#   '00477528',
#   '00477382',
#   '00269423',
#   '02852523',
#   '08642145',
#   '13914608',
#   '07954014',
#   '02853016',
#   '13626464',
#   '05645199',
#   '04020298',
#   '03288225',
#   '02853449',
#   '02756601',
#   '00562398'],
#  'block_off': ['01126961', '01478002', '01477394'],
#  'block_out': ['00711236', '01477538', '01358737', '01006699'],
#  'block_up': ['01478002'],
#  'blockade': ['02557199',
#   '01478002',
#   '01126961',
#   '01126846',
#   '00954086',
#   '02853218'],
#  'blog': ['00865280', '06402202'],
#  'blood': ['01233642',
#   '05399847',
#   '04628747',
#   '10505942',
#   '08101937',
#   '07944618'],
#  'bloody': ['00228127', '00247439', '01520655', '00025144'],
#  'bloom': ['00294245',
#   '13439390',
#   '11669335',
#   '15151641',
#   '14050871',
#   '15295045',
#   '11410527'],
#  'blossom': ['00294245', '00293760', '11669335', '15295045'],
#  'blossom_forth': ['00293760'],
#  'blossom_out': ['00293760'],
#  'blot': ['01538928', '01531998', '04694441', '00072261'],
#  'blot_out': ['00313987'],
#  'blotch': ['01696135', '04694809'],
#  'bloviate': ['00829014'],
#  'blow': ['00007012',
#   '02769241',
#   '00034948',
#   '01902783',
#   '02135877',
#   '00477247',
#   '02527651',
#   '02268351',
#   '02266148',
#   '02178340',
#   '02135727',
#   '02117170',
#   '02101046',
#   '02100632',
#   '02068745',
#   '01849054',
#   '01545208',
#   '00934965',
#   '00883226',
#   '00779804',
#   '00435294',
#   '00310155',
#   '01173038',
#   '07338681',
#   '07475870',
#   '07298982',
#   '11465017',
#   '03066743',
#   '00835501'],
#  'blow-dry': ['00219224'],
#  'blow_a_fuse': ['01795428'],
#  'blow_off': ['01290945'],
#  "blow_one's_stack": ['01795428'],
#  'blow_out': ['00435294', '02761897', '02761012'],
#  'blow_out_of_the_water': ['01809064'],
#  'blow_over': ['00421691'],
#  'blow_up': ['00306723',
#   '00240293',
#   '01795428',
#   '00956405',
#   '00306298',
#   '00264386',
#   '00264034',
#   '00263682'],
#  'blub': ['00067274'],
#  'blubber': ['00067274', '00943732', '14781989', '04999401'],
#  'blubber_out': ['00943732'],
#  'bludgeon': ['02505606', '01423929', '02855793'],
#  'blue': ['00521641',
#   '00370869',
#   '01606058',
#   '00703615',
#   '00425002',
#   '02132224',
#   '01590484',
#   '01300370',
#   '00364881',
#   '04968895',
#   '02855925',
#   '08480847',
#   '09224566',
#   '14986593',
#   '02703692',
#   '02282257'],
#  'blue-pencil': ['00200863'],
#  'blueprint': ['01683582', '05902327', '02856109'],
#  'bluff': ['01076953',
#   '00837872',
#   '01145422',
#   '00764301',
#   '09224725',
#   '06759602',
#   '00756598'],
#  'bluff_out': ['01076953'],
#  'blunder': ['02566227', '02051547', '00981944', '00074790'],
#  'blunder_out': ['00981944'],
#  'blunt': ['00228019',
#   '02115273',
#   '01246444',
#   '00227913',
#   '00192051',
#   '01811683',
#   '00800464',
#   '00764484',
#   '00556881'],
#  'blur': ['02158034',
#   '02161758',
#   '00620673',
#   '01251928',
#   '00312990',
#   '00311113',
#   '05940414'],
#  'blurt': ['00981944'],
#  'blurt_out': ['00981944'],
#  'blush': ['00103317', '00289159', '14050871', '00118268'],
#  'bluster': ['02770362',
#   '00883226',
#   '00012434',
#   '13976182',
#   '06889591',
#   '11465297',
#   '07230089'],
#  'board': ['02018049',
#   '02656763',
#   '01177118',
#   '01176897',
#   '08322981',
#   '15101854',
#   '02856463',
#   '07565259',
#   '03211616',
#   '03201208',
#   '03098140',
#   '03033986',
#   '02857023'],
#  'board_up': ['01235224'],
#  'boast': ['00883226', '02631659', '07229530'],
#  'boat': ['01944692', '02858304', '03456024'],
#  'boat-race': ['01086854'],
#  'bob': ['01865383',
#   '01939811',
#   '01556178',
#   '00899352',
#   '00039121',
#   '13686877',
#   '05259109',
#   '02860847',
#   '02860239',
#   '02860063',
#   '02158066',
#   '00336274'],
#  'bob_about': ['01865866'],
#  'bob_around': ['01865866'],
#  'bob_under': ['02156963'],
#  'bob_up': ['02625786'],
#  'bobble': ['02527651', '00071864'],
#  'bobsled': ['01939811', '02861022', '02860847'],
#  'bode': ['00871942'],
#  'bodge': ['02527651'],
#  'body': ['02698944',
#   '05216365',
#   '07965085',
#   '05217859',
#   '09224911',
#   '05549830',
#   '08436288',
#   '04934546',
#   '06394701',
#   '05024616',
#   '04261506',
#   '02861886'],
#  'body-surf': ['01948339'],
#  'body_forth': ['02698443'],
#  'body_guard': ['02026868'],
#  'bodypaint': ['01681635'],
#  'bog': ['00363916', '00363742', '09225943'],
#  'bog_down': ['00363742', '01835103', '01834896', '00363916'],
#  ...}

# %%
synset_lemma_map
# Out:
# {'00865776': ['aah', 'ooh'],
#  '02168378': ['abacinate'],
#  '02228031': ['abandon'],
#  '02227741': ['abandon', 'give_up'],
#  '02076676': ['abandon', 'empty', 'vacate'],
#  '00613393': ['abandon', 'give_up'],
#  '00614057': ['abandon', 'desert', 'desolate', 'forsake'],
#  '01799794': ['abase', 'chagrin', 'humble', 'humiliate', 'mortify'],
#  '01792097': ['abash', 'embarrass'],
#  '00245289': ['abate', 'slack', 'slake'],
#  '00245059': ['abate', 'die_away', 'let_up', 'slack', 'slack_off'],
#  '00243900': ['abbreviate',
#   'abridge',
#   'contract',
#   'cut',
#   'foreshorten',
#   'reduce',
#   'shorten'],
#  '00243749': ['abbreviate'],
#  '02379198': ['abdicate', 'renounce'],
#  '01015866': ['abduce', 'adduce', 'cite'],
#  '01471043': ['abduct', 'kidnap', 'nobble', 'snatch'],
#  '01449427': ['abduct'],
#  '02662076': ['aberrate'],
#  '02661769': ['aberrate'],
#  '02549211': ['abet'],
#  '01774426': ['abhor', 'abominate', 'execrate', 'loathe'],
#  '02637202': ['abide', 'bide', 'stay'],
#  '00668099': ['abide',
#   'bear',
#   'brook',
#   'digest',
#   'endure',
#   'put_up',
#   'stand',
#   'stick_out',
#   'stomach',
#   'suffer',
#   'support',
#   'tolerate'],
#  '02542280': ['abide_by', 'comply', 'follow'],
#  '02457233': ['abide_by', 'honor', 'honour', 'observe', 'respect'],
#  '00798717': ['abjure', 'forswear', 'recant', 'resile', 'retract'],
#  '01186958': ['ablactate', 'wean'],
#  '00275466': ['ablate'],
#  '00177578': ['ablate'],
#  '02213074': ['abnegate', 'deny'],
#  '01116275': ['abnegate'],
#  '00758042': ['abnegate'],
#  '02427334': ['abolish', 'get_rid_of'],
#  '00353839': ['abort'],
#  '00060063': ['abort'],
#  '00059899': ['abort'],
#  '02715279': ['abound'],
#  '02715595': ['abound', 'bristle', 'burst'],
#  '02715923': ['abound_in', 'pullulate_with', 'teem_in'],
#  '01909042': ['about-face'],
#  '00689068': ['about-face'],
#  '01254013': ['abrade', 'abrase', 'corrade', 'rub_down', 'rub_off'],
#  '01251651': ['abrade', 'scour'],
#  '01815471': ['abreact'],
#  '00236843': ['abridge'],
#  '02478584': ['abrogate'],
#  '01255355': ['abscise'],
#  '01255222': ['abscise'],
#  '02073714': ['abscond',
#   'absquatulate',
#   'bolt',
#   'decamp',
#   'go_off',
#   'make_off',
#   'run_off'],
#  '01923058': ['abseil', 'rappel', 'rope_down'],
#  '00421535': ['absent', 'remove'],
#  '00903711': ['absolve', 'shrive'],
#  '00902424': ['absolve', 'free', 'justify'],
#  '01539633': ['absorb'],
#  '00602255': ['absorb', 'assimilate', 'ingest', 'take_in'],
#  '02216560': ['absorb', 'take_over'],
#  '01539063': ['absorb',
#   'draw',
#   'imbibe',
#   'soak_up',
#   'sop_up',
#   'suck',
#   'suck_up',
#   'take_in',
#   'take_up'],
#  '00395698': ['absorb'],
#  '02765464': ['absorb', 'take_in'],
#  '00601043': ['absorb',
#   'engross',
#   'engulf',
#   'immerse',
#   'plunge',
#   'soak_up',
#   'steep'],
#  '01470524': ['absorb'],
#  '00600370': ['absorb', 'engage', 'engross', 'occupy'],
#  '02463426': ['abstain'],
#  '01196037': ['abstain', 'desist', 'refrain'],
#  '00692329': ['abstract'],
#  '02276866': ['abstract',
#   'cabbage',
#   'filch',
#   'hook',
#   'lift',
#   'nobble',
#   'pilfer',
#   'pinch',
#   'purloin',
#   'snarf',
#   'sneak',
#   'swipe'],
#  '00734587': ['abstract'],
#  '01008288': ['abstract'],
#  '02516594': ['abuse', 'ill-treat', 'ill-use', 'maltreat', 'mistreat', 'step'],
#  '00203213': ['abuse', 'misuse', 'pervert'],
#  '00845299': ['abuse', 'blackguard', 'clapperclaw', 'shout'],
#  '00203556': ['abuse'],
#  '01466978': ['abut',
#   'adjoin',
#   'border',
#   'butt',
#   'butt_against',
#   'butt_on',
#   'edge',
#   'march'],
#  '02520509': ['aby', 'abye', 'atone', 'expiate'],
#  '00878348': ['accede', 'bow', 'defer', 'give_in', 'submit'],
#  '02381397': ['accede', 'enter'],
#  '00804139': ['accede', 'acquiesce', 'assent'],
#  '00438178': ['accelerate', 'quicken', 'speed', 'speed_up'],
#  '00439343': ['accelerate', 'speed', 'speed_up'],
#  '01013367': ['accent',
#   'accentuate',
#   'emphasise',
#   'emphasize',
#   'punctuate',
#   'stress'],
#  '00983333': ['accent', 'accentuate', 'stress'],
#  '00686447': ['accept'],
#  '02236124': ['accept', 'have', 'take'],
#  '00797697': ['accept', 'consent', 'go_for'],
#  '00719231': ['accept'],
#  '02236624': ['accept', 'admit', 'take', 'take_on'],
#  '02301825': ['accept', 'assume', 'bear', 'take_over'],
#  '00668805': ['accept', 'live_with', 'swallow'],
#  '02741546': ['accept', 'take'],
#  '02210622': ['accept'],
#  '02209936': ['accept', 'take'],
#  '00718489': ['accept'],
#  '02248808': ['access'],
#  '02007417': ['access', 'get_at'],
#  '00999568': ['accession'],
#  '00861725': ['acclaim', 'hail', 'herald'],
#  '00861929': ['acclaim', 'applaud', 'clap', 'spat'],
#  '00393677': ['acclimate', 'acclimatise', 'acclimatize'],
#  '02702830': ['accommodate', 'fit', 'suit'],
#  '00299580': ['accommodate', 'adapt'],
#  '01184453': ['accommodate'],
#  '02732798': ['accommodate', 'admit', 'hold'],
#  '02651424': ['accommodate', 'lodge'],
#  '00885925': ['accommodate', 'oblige'],
#  '00482893': ['accommodate', 'conciliate', 'reconcile'],
#  '02716165': ['accompany', 'attach_to', 'come_with', 'go_with'],
#  '02025550': ['accompany'],
#  '01728355': ['accompany', 'follow', 'play_along'],
#  '02716767': ['accompany', 'companion', 'company', 'keep_company'],
#  '01640855': ['accomplish',
#   'action',
#   'carry_out',
#   'carry_through',
#   'execute',
#   'fulfil',
#   'fulfill'],
#  '02526085': ['accomplish', 'achieve', 'attain', 'reach'],
#  '02700104': ['accord',
#   'agree',
#   'concord',
#   'consort',
#   'fit_in',
#   'harmonise',
#   'harmonize'],
#  '02255268': ['accord', 'allot', 'grant'],
#  '00990655': ['accost', 'address', 'come_up_to'],
#  '00781652': ['accost', 'hook', 'solicit'],
#  '02607432': ['account'],
#  '02265231': ['account', 'calculate'],
#  '00965035': ['account', 'describe', 'report'],
#  '00867644': ['account', 'answer_for'],
#  '02635033': ['account_for'],
#  '00939621': ['account_for'],
#  '02342016': ['accouter', 'accoutre'],
#  '02475535': ['accredit', 'recognise', 'recognize'],
#  '02475772': ['accredit'],
#  '00727791': ['accredit', 'credit'],
#  '00396325': ['accrete'],
#  '00159368': ['accrete'],
#  '00155869': ['accrue'],
#  '02230056': ['accrue', 'fall'],
#  '00159880': ['acculturate'],
#  '02304982': ['accumulate',
#   'amass',
#   'collect',
#   'compile',
#   'hoard',
#   'pile_up',
#   'roll_up'],
#  '00158804': ['accumulate',
#   'amass',
#   'conglomerate',
#   'cumulate',
#   'gather',
#   'pile_up'],
#  '00864910': ['accurse',
#   'anathematise',
#   'anathematize',
#   'anathemise',
#   'anathemize',
#   'comminate',
#   'execrate'],
#  '00842989': ['accuse', 'criminate', 'impeach', 'incriminate'],
#  '00843468': ['accuse', 'charge'],
#  '00273445': ['accustom', 'habituate'],
#  '02522581': ['ace',
#   'breeze_through',
#   'nail',
#   'pass_with_flying_colors',
#   'sail_through',
#   'sweep_through'],
#  '01113367': ['ace'],
#  '01085130': ['ace'],
#  '01077759': ['ace'],
#  '01773535': ['acerbate', 'embitter', 'envenom'],
#  '00270440': ['acerbate'],
#  '02196690': ['acetify', 'acidify', 'acidulate', 'sour'],
#  '00264875': ['acetify', 'acidify'],
#  '00524299': ['acetylate', 'acetylise', 'acetylize'],
#  '00524083': ['acetylate', 'acetylise', 'acetylize'],
#  '02121511': ['ache', 'hurt', 'suffer'],
#  '01805684': ['ache', 'languish', 'pine', 'yearn', 'yen'],
#  '02122164': ['ache', 'hurt', 'smart'],
#  '00524530': ['achromatise', 'achromatize'],
#  '01537271': ['acid-wash'],
#  '00817311': ['acknowledge', 'admit'],
#  '00892698': ['acknowledge', 'receipt'],
#  '01059123': ['acknowledge', 'notice'],
#  '00892467': ['acknowledge', 'recognise', 'recognize'],
#  '00740449': ['acknowledge'],
#  '00592883': ['acknowledge', 'know', 'recognise', 'recognize'],
#  '00901103': ['acquaint', 'introduce', 'present'],
#  '00874175': ['acquaint', 'familiarise', 'familiarize'],
#  '00832778': ['acquaint'],
#  '02210855': ['acquire', 'get'],
#  '00524682': ['acquire', 'adopt', 'assume', 'take', 'take_on'],
#  '00094460': ['acquire', 'develop', 'get', 'grow', 'produce'],
#  '02695378': ['acquire'],
#  '02288295': ['acquire', 'gain', 'win'],
#  '00597915': ['acquire', 'larn', 'learn'],
#  '00545557': ['acquire', 'develop', 'evolve'],
#  '00904046': ['acquit',
#   'assoil',
#   'clear',
#   'discharge',
#   'exculpate',
#   'exonerate'],
#  '02518161': ['acquit',
#   'bear',
#   'behave',
#   'carry',
#   'comport',
#   'conduct',
#   'deport'],
#  '02367363': ['act', 'move'],
#  '00010435': ['act', 'behave', 'do'],
#  '01719302': ['act', 'play', 'represent'],
#  '01095899': ['act'],
#  '00013615': ['act', 'act_as', 'play'],
#  '02744977': ['act'],
#  '02525447': ['act', 'work'],
#  '02419073': ['act'],
#  '01721556': ['act', 'dissemble', 'pretend'],
#  '01719921': ['act', 'play', 'playact', 'roleplay'],
#  '02671613': ['act_as'],
#  '00010241': ['act_involuntarily', 'act_reflexively'],
#  '02376429': ['act_on', 'follow_up_on', 'pursue'],
#  '02376631': ['act_on'],
#  '01722645': ['act_out'],
#  '01722447': ['act_out', 'enact', 'reenact'],
#  '02593551': ['act_superior', 'lord_it_over', 'put_on_airs', 'queen_it_over'],
#  '02517655': ['act_up', 'carry_on'],
#  '02122522': ['act_up'],
#  '02536557': ['act_upon', 'influence', 'work'],
#  '02582042': ['action', 'litigate', 'process', 'sue'],
#  '01643657': ['activate',
#   'actuate',
#   'set_off',
#   'spark',
#   'spark_off',
#   'touch_off',
#   'trigger',
#   'trigger_off',
#   'trip'],
#  '00190682': ['activate'],
#  '00191385': ['activate'],
#  '00190999': ['activate', 'aerate'],
#  '00190886': ['activate'],
#  '01644746': ['actualise', 'actualize', 'realise', 'realize', 'substantiate'],
#  '00987870': ['actualise', 'actualize'],
#  '01649999': ['actuate', 'incite', 'motivate', 'move', 'prompt', 'propel'],
#  '00393227': ['acuminate'],
#  '01728840': ['ad-lib',
#   'extemporise',
#   'extemporize',
#   'improvise',
#   'improvize'],
#  '00150287': ['adapt', 'adjust', 'conform'],
#  '00182406': ['add'],
#  '01027174': ['add', 'append', 'supply'],
#  '02324478': ['add', 'bestow', 'bring', 'contribute', 'impart', 'lend'],
#  '00640828': ['add', 'add_together'],
#  '00949288': ['add',
#   'add_together',
#   'add_up',
#   'sum',
#   'sum_up',
#   'summate',
#   'tally',
#   'tot',
#   'tot_up',
#   'total',
#   'tote_up'],
#  '02745172': ['add'],
#  '00183757': ['add_on'],
#  '01328705': ['add_on', 'affix', 'append', 'supplement'],
#  '00157347': ['add_to'],
#  '02627363': ['add_up', 'amount', 'come'],
#  '02645007': ['add_up', 'amount', 'come', 'number', 'total'],
#  '02619612': ['add_up', 'make_sense'],
#  '01165290': ['addict', 'hook'],
#  '00620532': ['addle', 'muddle', 'puddle'],
#  '00210647': ['addle'],
#  '00897564': ['address', 'turn_to'],
#  '00989201': ['address', 'speak'],
#  '00990812': ['address', 'direct'],
#  '01150981': ['address'],
#  '01160899': ['address'],
#  '02601456': ['address', 'call'],
#  '02249018': ['address'],
#  '01033527': ['address', 'cover', 'deal', 'handle', 'plow', 'treat'],
#  '00464687': ['address'],
#  '01449236': ['adduct'],
#  '02718178': ['adhere'],
#  '00486557': ['adhere'],
#  '01220885': ['adhere', 'cleave', 'cling', 'cohere', 'stick'],
#  '02638845': ['adhere', 'stick'],
#  '02638630': ['adhere', 'stand_by', 'stick', 'stick_by'],
#  '01356750': ['adhere', 'bind', 'bond', 'hold_fast', 'stick', 'stick_to'],
#  '01205696': ['adjoin', 'contact', 'meet', 'touch'],
#  '00183383': ['adjoin'],
#  '00364297': ['adjourn', 'break_up', 'recess'],
#  '02428487': ['adjourn', 'retire', 'withdraw'],
#  '00822367': ['adjudge', 'declare', 'hold'],
#  '02501278': ['adjudicate', 'judge', 'try'],
#  '00698855': ['adjudicate', 'decide', 'resolve', 'settle'],
#  '00759657': ['adjure', 'beseech', 'bid', 'conjure', 'entreat', 'press'],
#  '00755331': ['adjure'],
#  '00296178': ['adjust', 'correct', 'set'],
#  '00464321': ['adjust', 'align', 'aline', 'line_up'],
#  '00298067': ['adjust'],
#  '00699334': ['adjust'],
#  '02295082': ['admeasure'],
#  '02431971': ['administer', 'administrate'],
#  '02309621': ['administer'],
#  '02294436': ['administer',
#   'allot',
#   'deal',
#   'deal_out',
#   'dish_out',
#   'dispense',
#   'distribute',
#   'dole_out',
#   'lot',
#   'mete_out',
#   'parcel_out',
#   'shell_out'],
#  '00081072': ['administer', 'dispense'],
#  '02603567': ['administer'],
#  '01827858': ['admire', 'look_up_to'],
#  '02164694': ['admire'],
#  '02502536': ['admit', 'allow_in', 'intromit', 'let_in'],
#  '02449847': ['admit', 'include', 'let_in'],
#  '02745486': ['admit', 'allow'],
#  '02741682': ['admit'],
#  '02671279': ['admit'],
#  '00396703': ['admix'],
#  '00870577': ['admonish', 'discourage', 'monish', 'warn'],
#  '00871195': ['admonish', 'caution', 'monish'],
#  '00824066': ['admonish', 'reprove'],
#  '00252710': ['adolesce'],
#  '02346895': ['adopt', 'espouse', 'follow'],
#  '02346724': ['adopt', 'borrow', 'take_over', 'take_up'],
#  '02381726': ['adopt', 'assume', 'take_on', 'take_over'],
#  '00413195': ['adopt', 'take_in'],
#  '01701311': ['adopt', 'dramatise', 'dramatize'],
#  '00601822': ['adopt',
#   'embrace',
#   'espouse',
#   'sweep_up',
#   'labor_secretary',
#   'secretary_of_labor'],
#  '01777817': ['adore'],
#  '01675963': ['adorn',
#   'beautify',
#   'decorate',
#   'embellish',
#   'grace',
#   'ornament'],
#  '02748927': ['adorn', 'beautify', 'deck', 'decorate', 'embellish', 'grace'],
#  '02386675': ['adorn', 'clothe', 'invest'],
#  '01540232': ['adsorb'],
#  '00880518': ['adulate'],
#  '00487748': ['adulterate', 'debase', 'dilute', 'load', 'stretch'],
#  '01006421': ['adumbrate', 'outline', 'sketch'],
#  '00927711': ['adumbrate', 'insinuate', 'intimate'],
#  '01992503': ['advance',
#   'go_on',
#   'march_on',
#   'move_on',
#   'pass_on',
#   'progress'],
#  '00875806': ['advance', 'throw_out'],
#  '00497061': ['advance', 'boost', 'supercharge'],
#  '02554922': ['advance', 'boost', 'encourage', 'further', 'promote'],
#  '01993926': ['advance', 'bring_forward'],
#  '01111028': ['advance',
#   'gain',
#   'gain_ground',
#   'get_ahead',
#   'make_headway',
#   'pull_ahead',
#   'win'],
#  '00248659': ['advance',
#   'come_along',
#   'come_on',
#   'get_along',
#   'get_on',
#   'progress',
#   'shape_up'],
#  '00558371': ['advance'],
#  '02397637': ['advance',
#   'elevate',
#   'kick_upstairs',
#   'promote',
#   'raise',
#   'upgrade'],
#  '02283949': ['advance'],
#  '01994288': ['advance', 'set_ahead'],
#  '00158222': ['advance', 'gain'],
#  '02513268': ['advantage'],
#  '02102655': ['advect'],
#  '02544348': ['adventure',
#   'chance',
#   'gamble',
#   'hazard',
#   'risk',
#   'run_a_risk',
#   'take_a_chance',
#   'take_chances'],
#  '02545272': ['adventure', 'hazard', 'jeopardize', 'stake', 'venture'],
#  '02170427': ['advert', 'attend', 'give_ear', 'hang', 'pay_heed'],
#  '01026728': ['advert', 'allude', 'touch'],
#  '01024190': ['advert', 'bring_up', 'cite', 'mention', 'name', 'refer'],
#  '00975902': ['advertise', 'advertize', 'publicise', 'publicize'],
#  '00976653': ['advertise', 'advertize', 'promote', 'push'],
#  '00872886': ['advise', 'counsel', 'rede'],
#  '00873682': ['advise',
#   'apprise',
#   'apprize',
#   'give_notice',
#   'notify',
#   'send_word'],
#  '00875394': ['advise', 'propose', 'suggest'],
#  '00875141': ['advocate', 'recommend', 'urge'],
#  '00827730': ['advocate', 'preach'],
#  '02112891': ['aerate', 'air', 'air_out', 'cosignatory'],
#  '00185465': ['aerate', 'oxygenate', 'oxygenise', 'oxygenize'],
#  '00442267': ['aerify', 'gasify', 'vaporise', 'vaporize'],
#  '01377940': ['aerosolise', 'aerosolize'],
#  '01377758': ['aerosolise', 'aerosolize'],
#  '00016183': ['aestivate', 'estivate'],
#  '00137313': ['affect', 'bear_on', 'bear_upon', 'impact', 'touch', 'touch_on'],
#  '00019448': ['affect'],
#  '02677097': ['affect', 'involve', 'regard'],
#  '00838043': ['affect', 'dissemble', 'feign', 'pretend', 'sham'],
#  '01767949': ['affect', 'impress', 'move', 'strike'],
#  '00886602': ['affiance', 'betroth', 'engage', 'plight'],
#  '02589245': ['affiliate', 'associate', 'assort', 'consort'],
#  '02435311': ['affiliate'],
#  '00665886': ['affirm',
#   'confirm',
#   'corroborate',
#   'substantiate',
#   'support',
#   'sustain'],
#  '01011031': ['affirm', 'assert', 'aver', 'avow', 'swan', 'swear', 'verify'],
#  '01011725': ['affirm'],
#  '01356370': ['affix', 'stick_on'],
#  '01298283': ['affix'],
#  '01797730': ['afflict'],
#  '00259927': ['afflict', 'smite'],
#  '01192628': ['afford'],
#  '02339171': ['afford', 'give', 'yield'],
#  '02744451': ['afford'],
#  '02358034': ['afford', 'give', 'open'],
#  '01567888': ['afforest', 'forest'],
#  '02477135': ['affranchise', 'enfranchise'],
#  '01779165': ['affright', 'fright', 'frighten', 'scare'],
#  '00848420': ['affront', 'diss', 'insult'],
#  '00248512': ['age'],
#  '00248026': ['age', 'get_on', 'maturate', 'mature', 'senesce'],
#  '00249679': ['age'],
#  '00517365': ['agenise', 'agenize'],
#  '01484714': ['agglomerate'],
#  '01222016': ['agglutinate'],
#  '01221684': ['agglutinate'],
#  '01307771': ['aggrade'],
#  '00956405': ['aggrandise',
#   'aggrandize',
#   'blow_up',
#   'dramatise',
#   'dramatize',
#   'embellish',
#   'embroider',
#   'lard',
#   'pad'],
#  '00208210': ['aggravate', 'exacerbate', 'exasperate', 'worsen'],
#  '01820901': ['aggravate', 'exacerbate', 'exasperate'],
#  '02627555': ['aggregate'],
#  '01385170': ['aggregate', 'combine'],
#  '01118449': ['aggress', 'attack'],
#  '02513879': ['aggrieve'],
#  '01797582': ['aggrieve', 'grieve'],
#  '01089878': ['aggroup', 'group'],
#  '02585050': ['agitate', 'foment', 'stir_up'],
#  '01762528': ['agitate',
#   'charge',
#   'charge_up',
#   'commove',
#   'excite',
#   'rouse',
#   'turn_on'],
#  '02589576': ['agitate', 'campaign', 'crusade', 'fight', 'press', 'push'],
#  '01893988': ['agitate', 'budge', 'shift', 'stir'],
#  '01889610': ['agitate', 'shake'],
#  '01419473': ['agitate',
#   'commove',
#   'disturb',
#   'raise_up',
#   'shake_up',
#   'stir_up',
#   'vex'],
#  '00728617': ['agnise',
#   'agnize',
#   'realise',
#   'realize',
#   'recognise',
#   'recognize'],
#  '01794523': ['agonise', 'agonize'],
#  '01794363': ['agonise', 'agonize'],
#  '00805376': ['agree', 'concord', 'concur', 'hold'],
#  '00764222': ['agree'],
#  '02657219': ['agree',
#   'check',
#   'correspond',
#   'fit',
#   'gibe',
#   'jibe',
#   'match',
#   'tally'],
#  '02741793': ['agree'],
#  '02291135': ['agree'],
#  '01035530': ['agree'],
#  '02547586': ['aid', 'assist', 'help'],
#  '00082081': ['aid', 'help', 'marketing'],
#  '00078665': ['ail'],
#  '00070816': ['ail', 'pain', 'trouble'],
#  '01151110': ['aim', 'direct', 'take', 'take_aim', 'train'],
#  '00708980': ['aim', 'propose', 'purport', 'purpose'],
#  '01026975': ['aim', 'drive', 'get'],
#  '00713015': ['aim', 'calculate', 'direct'],
#  '01150559': ['aim', 'direct', 'place', 'point', 'target'],
#  '00955472': ['aim'],
#  '00705517': ['aim', 'aspire', 'draw_a_bead_on', 'shoot_for'],
#  '00973728': ['air'],
#  '00973056': ['air', 'beam', 'broadcast', 'send', 'transmit'],
#  '00954608': ['air', 'bare', 'publicise', 'publicize'],
#  '00489029': ['air'],
#  '00488770': ['air', 'air_out', 'vent', 'ventilate'],
#  '02331575': ['air-condition'],
#  '02331326': ['air-condition', 'air-cool'],
#  '01489859': ['air-drop'],
#  '01951159': ['air-freight', 'air-ship', 'airfreight'],
#  '00214794': ['air-slake', 'transactional_immunity'],
#  '01363320': ['airbrush'],
#  '01452057': ['airlift', 'lift'],
#  '01032127': ['airmail'],
#  '01953334': ['airt', 'redirect'],
#  '01782650': ['alarm', 'appal', 'appall', 'dismay', 'horrify'],
#  '00872414': ['alarm', 'alert'],
#  '00139586': ['alchemise', 'alchemize'],
#  '00139908': ['alcoholise', 'alcoholize'],
#  '00139729': ['alcoholise', 'alcoholize'],
#  '01176734': ['alcoholize'],
#  '00893741': ['alibi'],
#  '02221010': ['alien', 'alienate'],
#  '01823528': ['alien', 'alienate', 'disaffect', 'estrange'],
#  '01823888': ['alienate'],
#  '01978700': ['alight', 'light', 'perch'],
#  '01978576': ['alight', 'climb_down'],
#  '02658867': ['align'],
#  '00733632': ['align', 'array', 'plummy'],
#  '00466053': ['align', 'coordinate', 'ordinate'],
#  '01204191': ['aliment', 'nourish', 'nutrify'],
#  '00265094': ['alkalify', 'alkalise', 'alkalize', 'basify'],
#  '00134898': ['alkalinise', 'alkalinize'],
#  '00134737': ['alkalinise', 'alkalinize'],
#  '01815185': ['allay', 'ease', 'relieve', 'still'],
#  '01204021': ['allay', 'assuage', 'quench', 'slake'],
#  '01016002': ['allege', 'aver', 'say'],
#  '00624263': ['allegorise', 'allegorize'],
#  '00135285': ['allegorise', 'allegorize'],
#  '00064095': ['alleviate', 'assuage', 'palliate', 'relieve'],
#  '00518395': ['alleviate', 'ease', 'facilitate'],
#  '00337700': ['alligator'],
#  '01702154': ['alliterate'],
#  '02234087': ['allocate', 'apportion'],
#  '02228698': ['allot', 'assign', 'portion'],
#  '02423183': ['allow', 'let', 'permit'],
#  '00802318': ['allow', 'countenance', 'let', 'permit'],
#  '02255462': ['allow', 'grant'],
#  '00724150': ['allow', 'appropriate', 'earmark', 'reserve', 'set_aside'],
#  '02721438': ['allow', 'allow_for', 'leave', 'provide'],
#  '00723545': ['allow', 'take_into_account'],
#  '02423650': ['allow', 'give_up'],
#  '02319669': ['allow'],
#  '00802946': ['allow', 'permit', 'tolerate'],
#  '02255821': ['allowance'],
#  '00493517': ['alloy', 'debase'],
#  '00396880': ['alloy'],
#  '00793785': ['allure', 'tempt'],
#  '02430191': ['ally'],
#  '02434737': ['ally_with'],
#  '00279239': ['alphabetise', 'alphabetize'],
#  '02330967': ['alphabetize'],
#  '00126264': ['alter', 'change', 'modify'],
#  '00123170': ['alter', 'change', 'vary'],
#  '01667132': ['alter'],
#  '00201407': ['alter', 'falsify', 'interpolate'],
#  '00060477': ['alter', 'castrate', 'neuter', 'spay'],
#  '00775156': ['altercate', 'argufy', 'dispute', 'quarrel', 'scrap'],
#  '00121506': ['alternate', 'jump'],
#  '02393726': ['alternate'],
#  '00604930': ['alternate', 'understudy'],
#  '00121678': ['alternate',
#   'flip',
#   'flip-flop',
#   'interchange',
#   'switch',
#   'tack'],
#  '00121214': ['alternate', 'take_turns'],
#  '01338113': ['aluminise', 'aluminize'],
#  '01462005': ['amalgamate', 'commix', 'mingle', 'mix', 'unify'],
#  '00724832': ['amaze', 'astonish', 'astound'],
#  '00622384': ['amaze',
#   'baffle',
#   'beat',
#   'bewilder',
#   'dumbfound',
#   'flummox',
#   'get',
#   'gravel',
#   'mystify',
#   'nonplus',
#   'perplex',
#   'pose',
#   'puzzle',
#   'stick',
#   'stupefy',
#   'vex'],
#  '01826060': ['ambition'],
#  '01918183': ['amble', 'mosey'],
#  '01911698': ['ambulate'],
#  '01138204': ['ambuscade',
#   'ambush',
#   'bushwhack',
#   'lie_in_wait',
#   'lurk',
#   'scupper',
#   'waylay'],
#  '01142203': ['ambush', 'still-hunt'],
#  '00205885': ['ameliorate', 'amend', 'better', 'improve', 'meliorate'],
#  '00205046': ['ameliorate', 'better', 'improve', 'meliorate'],
#  '00996328': ['amend'],
#  '00199912': ['amend', 'rectify', 'remediate', 'remedy', 'repair'],
#  '02500265': ['amerce'],
#  '02498987': ['amerce'],
#  '00410406': ['americanise', 'americanize'],
#  '00409643': ['americanise', 'americanize'],
#  '00187147': ['ammoniate'],
#  '00497219': ['ammonify', 'worthlessly'],
#  '00905677': ['amnesty'],
#  '02352263': ['amortise', 'amortize'],
#  '02664992': ['amount'],
#  '00434077': ['amplify', 'magnify'],
#  '00839834': ['amplify',
#   'exaggerate',
#   'hyperbolise',
#   'hyperbolize',
#   'magnify',
#   'overdraw',
#   'overstate'],
#  '00264386': ['amplify', 'blow_up', 'expand', 'inflate'],
#  '00263904': ['amplify'],
#  '01254692': ['amputate', 'cut_off'],
#  '02492362': ['amuse', 'disport', 'divert'],
#  '00859758': ['amuse'],
#  '00021065': ['anaesthetise',
#   'anaesthetize',
#   'anesthetise',
#   'anesthetize',
#   'put_out',
#   'put_under'],
#  '00625518': ['anagram', 'anagrammatise', 'anagrammatize'],
#  '00653283': ['analogise', 'analogize'],
#  '00644583': ['analyse', 'analyze', 'canvas', 'canvass', 'examine', 'study'],
#  '00736216': ['analyse', 'analyze'],
#  '00643473': ['analyse', 'analyze', 'break_down', 'dissect', 'take_apart'],
#  '00643197': ['analyse', 'analyze', 'psychoanalyse', 'psychoanalyze'],
#  '01292366': ['anastomose', 'inosculate'],
#  '01292169': ['anastomose', 'inosculate'],
#  '00865958': ['anathemise',
#   'anathemize',
#   'bedamn',
#   'beshrew',
#   'curse',
#   'damn',
#   'imprecate',
#   'maledict'],
#  '01550594': ['anatomise', 'anatomize'],
#  '00645241': ['anatomize'],
#  '01304944': ['anchor', 'ground'],
#  '01304716': ['anchor', 'cast_anchor', 'drop_anchor'],
#  '00096396': ['ancylose', 'ankylose'],
#  '00096264': ['ancylose', 'ankylose'],
#  '00085626': ['anele', 'anoint', 'embrocate', 'inunct', 'oil'],
#  '01785971': ['anger'],
#  '01787106': ['anger', 'see_red'],
#  '02044866': ['angle'],
#  '02038357': ['angle', 'lean', 'slant', 'tilt', 'tip'],
#  '01319346': ['angle', 'fish'],
#  '01141612': ['angle'],
#  '00680485': ['angle', 'slant', 'weight'],
#  '01934731': ['angle-park'],
#  '00300317': ['anglicise', 'anglicize'],
#  '01794969': ['anguish'],
#  '01792567': ['anguish', 'hurt', 'pain'],
#  '00573457': ['angulate'],
#  '01027668': ['animadvert', 'opine', 'sound_off', 'speak_out', 'speak_up'],
#  '00827158': ['animadvert'],
#  '01680756': ['animalise', 'animalize'],
#  '00114052': ['animalise', 'animalize', 'brutalise', 'brutalize'],
#  '00113853': ['animalise', 'animalize', 'brutalise', 'brutalize'],
#  '01812720': ['animate', 'enliven', 'exalt', 'inspire', 'invigorate'],
#  '00547995': ['animate', 'animise', 'animize'],
#  '00192836': ['animate', 'enliven', 'invigorate', 'liven', 'liven_up'],
#  '00024279': ['animate',
#   'quicken',
#   'reanimate',
#   'recreate',
#   'renovate',
#   'repair',
#   'revive',
#   'revivify',
#   'vivify'],
#  '00303056': ['anneal', 'normalize', 'temper'],
#  '02215355': ['annex'],
#  '01329141': ['annex'],
#  '00470701': ['annihilate',
#   'carry_off',
#   'decimate',
#   'eliminate',
#   'eradicate',
#   'extinguish',
#   'wipe_out'],
#  '01704953': ['annotate', 'footnote'],
#  '00961329': ['annotate', 'comment', 'gloss'],
#  '00974367': ['announce', 'denote'],
#  '00965871': ['announce', 'declare'],
#  '00975427': ['announce'],
#  '00974173': ['announce', 'annunciate', 'foretell', 'harbinger', 'herald'],
#  '01787955': ['annoy',
#   'bother',
#   'chafe',
#   'devil',
#   'get_at',
#   'get_to',
#   'gravel',
#   'irritate',
#   'nark',
#   'nettle',
#   'rag',
#   'rile',
#   'vex'],
#  '02478059': ['annul', 'avoid', 'invalidate', 'nullify', 'quash', 'void'],
#  '00799798': ['annul',
#   'countermand',
#   'lift',
#   'overturn',
#   'repeal',
#   'rescind',
#   'reverse',
#   'revoke',
#   'vacate'],
#  '00136567': ['anodise', 'anodize'],
#  '00675412': ['anoint'],
#  '00815686': ['answer', 'reply', 'respond'],
#  '00719590': ['answer'],
#  '00636279': ['answer'],
#  '00635523': ['answer', 'resolve'],
#  '00815171': ['answer'],
#  '02746017': ['answer'],
#  '02669789': ['answer', 'do', 'serve', 'suffice'],
#  '02658570': ['answer'],
#  '01183896': ['answer'],
#  '00718308': ['answer'],
#  '02564841': ['antagonise', 'antagonize', 'counteract'],
#  '01807314': ['antagonise', 'antagonize'],
#  '01139380': ['ante'],
#  '02252931': ['ante_up', 'pay', 'pay_up'],
#  '02712443': ['antecede', 'antedate', 'forego', 'forgo', 'precede', 'predate'],
#  '00277086': ['antedate', 'foredate', 'predate'],
#  '01626705': ['anthologise', 'anthologize'],
#  '00727409': ['anthropomorphise', 'anthropomorphize'],
#  '00105778': ['antic', 'clown', 'clown_around'],
#  '00719734': ['anticipate', 'expect'],
#  '02565491': ['anticipate', 'counter', 'foresee', 'forestall'],
#  '00720808': ['anticipate', 'foreknow', 'foresee', 'previse'],
#  '00917772': ['anticipate',
#   'call',
#   'forebode',
#   'foretell',
#   'predict',
#   'prognosticate',
#   'promise'],
#  '01804961': ['anticipate', 'look_for', 'look_to'],
#  '00342640': ['anticipate'],
#  '00253664': ['antiquate'],
#  '00253501': ['antiquate', 'antique'],
#  '02326795': ['antique'],
#  '00062774': ['antisepticize'],
#  '02675067': ['ape'],
#  '00849592': ['ape', 'caricature'],
#  '00741911': ['aphorise', 'aphorize'],
#  '00894738': ['apologise',
#   'apologize',
#   'excuse',
#   'justify',
#   'rationalise',
#   'rationalize'],
#  '00892923': ['apologise', 'apologize'],
#  '00757856': ['apostatise', 'apostatize', 'tergiversate'],
#  '00993754': ['apostrophise', 'apostrophize'],
#  '00693633': ['apotheose', 'apotheosise', 'apotheosize'],
#  '01810447': ['appal',
#   'appall',
#   'offend',
#   'outrage',
#   'scandalise',
#   'scandalize',
#   'shock'],
#  '00047945': ['apparel',
#   'clothe',
#   'dress',
#   'enclothe',
#   'fit_out',
#   'garb',
#   'garment',
#   'habilitate',
#   'raiment',
#   'tog'],
#  '02497586': ['appeal'],
#  '00755447': ['appeal', 'invoke'],
#  '01807882': ['appeal', 'attract'],
#  '02497824': ['appeal'],
#  '01024864': ['appeal', 'invoke'],
#  '02133435': ['appear', 'look', 'seem'],
#  '00422090': ['appear'],
#  '00425967': ['appear', 'come_out'],
#  '02134672': ['appear', 'seem'],
#  '00425071': ['appear', 'come_along'],
#  '01721169': ['appear'],
#  '02597762': ['appear'],
#  '01765392': ['appease',
#   'assuage',
#   'conciliate',
#   'gentle',
#   'gruntle',
#   'lenify',
#   'mollify',
#   'pacify',
#   'placate'],
#  '01194114': ['appease', 'quell', 'stay'],
#  '00765213': ['appease', 'propitiate'],
#  '01328513': ['append', 'hang_on', 'tack', 'tack_on', 'tag_on'],
#  '02107097': ['apperceive'],
#  '02653706': ['appertain', 'pertain'],
#  '00860292': ['applaud'],
#  '01670777': ['applique'],
#  '01158872': ['apply', 'employ', 'use', 'utilise', 'utilize'],
#  '02676789': ['apply', 'go_for', 'hold'],
#  '00765396': ['apply'],
#  '01363648': ['apply', 'put_on'],
#  '02707429': ['apply', 'lend_oneself', 'cubital'],
#  '02309165': ['apply', 'give'],
#  '02561332': ['apply', 'practice', 'use'],
#  '02560164': ['apply', 'enforce', 'implement'],
#  '01026558': ['apply'],
#  '02595523': ['apply'],
#  '02396205': ['appoint', 'constitute', 'name', 'nominate'],
#  '02475922': ['appoint', 'charge'],
#  '02341370': ['appoint'],
#  '02294179': ['apportion', 'deal', 'divvy_up', 'portion_out', 'share'],
#  '01500214': ['appose'],
#  '00681429': ['appraise', 'assess', 'evaluate', 'measure', 'valuate', 'value'],
#  '00646542': ['appraise', 'survey'],
#  '01805982': ['appreciate'],
#  '00592341': ['appreciate', 'take_account'],
#  '02256109': ['appreciate', 'prize', 'treasure', 'value'],
#  '00316195': ['appreciate', 'apprise', 'apprize', 'revalue'],
#  '00315605': ['appreciate', 'apprise', 'apprize'],
#  '00588221': ['apprehend',
#   'compass',
#   'comprehend',
#   'dig',
#   'get_the_picture',
#   'grasp',
#   'grok',
#   'savvy'],
#  '01215137': ['apprehend',
#   'arrest',
#   'collar',
#   'cop',
#   'nab',
#   'nail',
#   'pick_up'],
#  '01782432': ['apprehend', 'quail_at'],
#  '00602635': ['apprentice'],
#  '00831074': ['apprise', 'apprize', 'instruct'],
#  '02053941': ['approach',
#   'come_near',
#   'come_on',
#   'draw_close',
#   'draw_near',
#   'go_up',
#   'near'],
#  '02703952': ['approach', 'border_on'],
#  '02439281': ['approach', 'go_about', 'set_about'],
#  '01849746': ['approach', 'come_near'],
#  '00990392': ['approach'],
#  '00803815': ['approbate'],
#  '00687033': ['approbate'],
#  '02272549': ['appropriate', 'capture', 'conquer', 'seize'],
#  '00806502': ['approve', 'o.k.', 'okay', 'sanction'],
#  '00673983': ['approve'],
#  '02666060': ['approximate', 'come_close'],
#  '00672433': ['approximate', 'estimate', 'gauge', 'guess', 'judge'],
#  '01956512': ['aquaplane'],
#  '01942854': ['aquaplane'],
#  '01750668': ['aquatint'],
#  '02260959': ['arbitrage'],
#  '00760956': ['arbitrate', 'intercede', 'intermediate', 'liaise', 'mediate'],
#  '00329495': ['arborise', 'arborize'],
#  '02034986': ['arc', 'arch', 'curve'],
#  '02035315': ['arch_over', 'overarch'],
#  '00522068': ['archaise', 'archaize'],
#  '01384638': ['archive', 'file_away'],
#  '00772189': ['argue', 'reason'],
#  '00773432': ['argue', 'contend', 'debate', 'fence'],
#  '00772640': ['argue', 'indicate'],
#  '02624263': ['arise',
#   'develop',
#   'grow',
#   'originate',
#   'rise',
#   'spring_up',
#   'uprise'],
#  '02625786': ['arise', 'bob_up', 'come_up'],
#  '01983264': ['arise', 'get_up', 'rise', 'stand_up', 'uprise'],
#  '00339738': ['arise', 'come_up'],
#  '01968569': ['arise',
#   'come_up',
#   'go_up',
#   'lift',
#   'move_up',
#   'rise',
#   'uprise'],
#  '02583139': ['arise', 'rebel', 'rise', 'rise_up'],
#  '00018158': ['arise', 'get_up', 'rise', 'turn_out', 'uprise'],
#  '01087197': ['arm', 'build_up', 'fortify', 'gird'],
#  '02334867': ['arm'],
#  '02341684': ['armor', 'armour'],
#  '02126382': ['aromatise', 'aromatize', 'perfume'],
#  '01759326': ['arouse',
#   'elicit',
#   'enkindle',
#   'evoke',
#   'fire',
#   'kindle',
#   'provoke',
#   'raise'],
#  '00018526': ['arouse',
#   'awake',
#   'awaken',
#   'come_alive',
#   'wake',
#   'wake_up',
#   'waken'],
#  '01629958': ['arouse',
#   'bring_up',
#   'call_down',
#   'call_forth',
#   'conjure',
#   'conjure_up',
#   'evoke',
#   'invoke',
#   'put_forward',
#   'raise',
#   'stir'],
#  '00022686': ['arouse',
#   'brace',
#   'energise',
#   'energize',
#   'perk_up',
#   'stimulate'],
#  '00018813': ['arouse', 'awaken', 'rouse', 'wake', 'wake_up', 'waken'],
#  '01894164': ['arouse', 'stir'],
#  '01762283': ['arouse', 'excite', 'sex', 'turn_on', 'wind_up'],
#  '02497992': ['arraign'],
#  '00843852': ['arraign'],
#  '01463963': ['arrange', 'set_up'],
#  '01021629': ['arrange', 'fix_up'],
#  '01648126': ['arrange', 'stage'],
#  '01745141': ['arrange', 'format'],
#  '00038849': ['arrange', 'coif', 'coiffe', 'coiffure', 'do', 'dress', 'set'],
#  '01706129': ['arrange', 'set'],
#  '00735571': ['arrange', 'order', 'put', 'set_up'],
#  '01474209': ['array', 'lay_out', 'range', 'set_out'],
#  '01131473': ['arrest', 'check', 'contain', 'hold_back', 'stop', 'turn_back'],
#  '01505958': ['arrest', 'catch', 'get'],
#  '01859586': ['arrest', 'halt', 'hold'],
#  '02005948': ['arrive', 'come', 'get'],
#  '02585860': ['arrive', 'get_in', 'go_far', 'make_it'],
#  '02020590': ['arrive_at', 'attain', 'gain', 'hit', 'make', 'reach'],
#  '02275365': ['arrogate', 'claim', 'lay_claim'],
#  '02276746': ['arrogate', 'assign'],
#  '02274482': ['arrogate', 'assume', 'seize', 'take_over', 'usurp'],
#  '02639606': ['arse_about',
#   'arse_around',
#   'bum',
#   'bum_about',
#   'bum_around',
#   'frig_around',
#   'fuck_off',
#   'loaf',
#   'loll',
#   'loll_around',
#   'lounge_about',
#   'lounge_around',
#   "waste_one's_time"],
#  '00854150': ['arse_around', 'fool', 'fool_around', 'horse_around'],
#  '00120095': ['arterialise',
#   'arterialize',
#   'at_the_same_time',
#   'simultaneously'],
#  '00885082': ['article'],
#  '02354287': ['articulate', 'joint'],
#  '00980453': ['articulate', 'formulate', 'give_voice', 'phrase', 'word'],
#  '00978549': ['articulate',
#   'enounce',
#   'enunciate',
#   'pronounce',
#   'say',
#   'sound_out'],
#  '02622637': ['articulate'],
#  '00978369': ['articulate', 'enunciate', 'vocalise', 'vocalize'],
#  '01969216': ['ascend', 'go_up'],
#  '02751451': ['ascend'],
#  '02381571': ['ascend'],
#  '02105657': ['ascend', 'climb_up'],
#  '02103021': ['ascend'],
#  '02037472': ['ascend'],
#  '01970348': ['ascend', 'come_up', 'rise', 'uprise'],
#  '01969779': ['ascend', 'move_up', 'rise'],
#  '00918872': ['ascertain', 'determine', 'find', 'find_out'],
#  '00662589': ['ascertain',
#   'assure',
#   'check',
#   'control',
#   'ensure',
#   'insure',
#   'see',
#   'see_to_it'],
#  '00920336': ['ascertain',
#   'check',
#   'determine',
#   'find_out',
#   'learn',
#   'see',
#   'watch'],
#  '00721302': ['ascertain'],
#  '00726300': ['ascribe', 'assign', 'attribute', 'impute'],
#  '00383437': ['ash'],
#  '00784342': ['ask', 'enquire', 'inquire'],
#  '00752493': ['ask'],
#  '00784727': ['ask'],
#  '00755745': ['ask', 'expect', 'require'],
#  '00897746': ['ask'],
#  '02627934': ['ask',
#   'call_for',
#   'demand',
#   'involve',
#   'necessitate',
#   'need',
#   'postulate',
#   'require',
#   'take'],
#  '01068565': ['ask'],
#  '01760143': ['ask_for', 'invite'],
#  '00351048': ['ask_for_it', 'ask_for_trouble'],
#  '01469770': ['ask_in', 'invite'],
#  '02486693': ['ask_out', 'invite_out', 'take_out'],
#  '02384686': ['ask_over', 'ask_round', 'invite'],
#  '00846509': ['asperse',
#   'besmirch',
#   'calumniate',
#   'defame',
#   'denigrate',
#   'slander',
#   'smear',
#   'smirch',
#   'sully'],
#  '01267866': ['asphalt'],
#  '01569181': ['asphyxiate', 'smother', 'suffocate'],
#  '01476180': ['asphyxiate', 'choke', 'stifle', 'suffocate'],
#  '00359511': ['asphyxiate', 'stifle', 'suffocate'],
#  '01540693': ['aspirate', 'draw_out', 'suck_out'],
#  '00952039': ['aspirate'],
#  '00003316': ['aspirate'],
#  '01120069': ['assail', 'assault', 'attack', 'set_on'],
#  '01119169': ['assail', 'attack'],
#  '00862683': ['assail', 'assault', 'attack', 'lash_out', 'round', 'snipe'],
#  '02483000': ['assassinate'],
#  '00847158': ['assassinate'],
#  '02567519': ['assault',
#   'dishonor',
#   'dishonour',
#   'outrage',
#   'rape',
#   'ravish',
#   'violate'],
#  '00694974': ['assay'],
#  '02530167': ['assay', 'attempt', 'essay', 'seek', 'try'],
#  '01656788': ['assemble',
#   'piece',
#   'put_together',
#   'set_up',
#   'tack',
#   'tack_together'],
#  '02428924': ['assemble', 'foregather', 'forgather', 'gather', 'meet'],
#  '02598143': ['assemble', 'gather', 'get_together'],
#  '01016778': ['assert', 'asseverate', 'maintain'],
#  '02373785': ['assert', 'put_forward'],
#  '00717045': ['assert', 'insist'],
#  '02519055': ['assert_oneself'],
#  '02308552': ['assess'],
#  '02308389': ['assess', 'tax'],
#  '00682230': ['assess'],
#  '01054027': ['assibilate'],
#  '00547022': ['assibilate'],
#  '02391803': ['assign', 'delegate', 'depute', 'designate'],
#  '00677683': ['assign', 'set_apart', 'specify'],
#  '01160370': ['assign', 'put'],
#  '02228531': ['assign'],
#  '00740053': ['assign', 'attribute'],
#  '00159642': ['assimilate'],
#  '00160261': ['assimilate'],
#  '01540042': ['assimilate', 'imbibe'],
#  '00160447': ['assimilate'],
#  '02414710': ['assist'],
#  '02540670': ['assist', 'attend', 'attend_to', 'serve', 'wait_on'],
#  '00713167': ['associate',
#   'colligate',
#   'connect',
#   'link',
#   'link_up',
#   'relate',
#   'tie_in'],
#  '02470175': ['associate', 'consociate'],
#  '02750642': ['assonate'],
#  '00654625': ['assort', 'class', 'classify', 'separate', 'sort', 'sort_out'],
#  '00632236': ['assume', 'presume', 'take_for_granted'],
#  '01982395': ['assume', 'strike', 'take', 'take_up'],
#  '01721754': ['assume', 'feign', 'sham', 'simulate'],
#  '01470856': ['assume'],
#  '00050652': ['assume', 'don', 'get_into', 'put_on', 'wear'],
#  '00890590': ['assure', 'ensure', 'guarantee', 'insure', 'secure'],
#  '01019643': ['assure', 'tell'],
#  '00776268': ['assure'],
#  '01766407': ['assure', 'reassure'],
#  '00884011': ['assure', 'promise'],
#  '00510869': ['asterisk', 'star'],
#  '01388386': ['astringe'],
#  '00304662': ['astringe'],
#  '01933766': ['astrogate'],
#  '01841947': ['astrogate'],
#  '01132980': ['atom-bomb', 'nuke'],
#  '01373138': ['atomise', 'atomize'],
#  '01133288': ['atomise', 'atomize', 'nuke', 'zap'],
#  '00330144': ['atomise', 'atomize'],
#  '01796800': ['atone', 'repent', 'moorcock'],
#  '00093979': ['atrophy'],
#  '01296462': ['attach'],
#  '01290255': ['attach'],
#  '01290422': ['attach'],
#  '02538086': ['attach', 'bind', 'bond', 'tie'],
#  '02273293': ['attach', 'confiscate', 'impound', 'seize', 'sequester'],
#  '02705535': ['attach_to', 'inhere_in'],
#  '00347610': ['attack'],
#  '00019792': ['attack'],
#  '02006834': ['attain', 'hit', 'reach'],
#  '02286687': ['attain',
#   'chance_on',
#   'chance_upon',
#   'come_across',
#   'come_upon',
#   'discover',
#   'fall_upon',
#   'happen_upon',
#   'light_upon',
#   'strike'],
#  '02547225': ['attaint', 'disgrace', 'dishonor', 'dishonour', 'shame'],
#  '02149501': ['attaint'],
#  '00170381': ['attemper'],
#  '01651293': ['attempt', 'set_about', 'undertake'],
#  '02612762': ['attend', 'go_to'],
#  '02549581': ['attend', 'look', 'see', 'take_care'],
#  '02716567': ['attend'],
#  '00616670': ['attend_to', 'take_to_heart'],
#  '00226379': ['attenuate', 'rarefy'],
#  '00220701': ['attenuate'],
#  '00820976': ['attest', 'certify', 'demonstrate', 'evidence', 'manifest'],
#  '00820352': ['attest'],
#  '01014821': ['attest', 'bear_witness', 'take_the_stand', 'testify'],
#  '00820611': ['attest'],
#  '00044149': ['attire',
#   'deck_out',
#   'deck_up',
#   'dress_up',
#   'fancy_up',
#   'fig_out',
#   'fig_up',
#   'get_up',
#   'gussy_up',
#   'overdress',
#   'prink',
#   'rig_out',
#   'tog_out',
#   'tog_up',
#   'trick_out',
#   'trick_up'],
#  '02519494': ['attitudinise', 'attitudinize'],
#  '00593200': ['attorn'],
#  '01505254': ['attract', 'draw', 'draw_in', 'pull', 'pull_in'],
#  '01350025': ['attract'],
#  '00297780': ['attune'],
#  '02244773': ['auction', 'auction_off', 'auctioneer'],
#  '00697062': ['audit', 'inspect', 'scrutinise', 'scrutinize'],
#  '00600235': ['audit'],
#  '01718535': ['audition', 'try_out'],
#  '00154388': ['augment'],
#  '00157950': ['augment'],
#  '00871942': ['augur',
#   'auspicate',
#   'betoken',
#   'bode',
#   'forecast',
#   'foreshadow',
#   'foretell',
#   'omen',
#   'portend',
#   'predict',
#   'prefigure',
#   'presage',
#   'prognosticate'],
#  '00918471': ['augur'],
#  '00382410': ['aurify'],
#  '00285231': ['aurify'],
#  '02150192': ['auscultate'],
#  '00347420': ['auspicate'],
#  '00664276': ['authenticate'],
#  '01704452': ['author'],
#  '02473981': ['authorise', 'authorize', 'empower'],
#  '00803325': ['authorise', 'authorize', 'clear', 'pass'],
#  '00062973': ['autoclave'],
#  '00997133': ['autograph', 'inscribe'],
#  '00479932': ['automate', 'automatise', 'automatize'],
#  '00480221': ['automatise', 'automatize'],
#  '01930738': ['automobile'],
#  '02150039': ['autopsy'],
#  '01513990': ['autotomise', 'autotomize'],
#  '01161561': ['avail'],
#  '02549048': ['avail'],
#  '01193569': ['avail', 'help'],
#  '01966706': ['avalanche', 'roll_down'],
#  '01153486': ['avenge', 'retaliate', 'revenge'],
#  '02645389': ['average', 'average_out'],
#  '02527294': ['average'],
#  '00639998': ['average', 'average_out'],
#  '02453321': ['avert',
#   'avoid',
#   'debar',
#   'deflect',
#   'fend_off',
#   'forefend',
#   'forfend',
#   'head_off',
#   'obviate',
#   'stave_off',
#   'ward_off'],
#  '02034511': ['avert', 'turn_away'],
#  '00124074': ['avianise', 'avianize'],
#  '01941093': ['aviate', 'fly', 'pilot'],
#  '00811375': ['avoid'],
#  '02463510': ['avoid'],
#  '01189823': ['avoid', 'keep_off'],
#  '00819923': ['avouch', 'avow'],
#  '02032117': ['avulse'],
#  '00720063': ['await', 'expect', 'look', 'wait'],
#  '00736095': ['awaken'],
#  '02261888': ['award', 'present'],
#  '02262278': ['award', 'grant'],
#  '01779644': ['awe'],
#  '01257953': ['ax', 'axe'],
#  '00354317': ['ax', 'axe'],
#  '00284958': ['azure'],
#  '01048330': ['baa', 'blat', 'blate', 'bleat'],
#  '01272349': ['babbitt'],
#  '01065630': ['babble'],
#  '01037650': ['babble', 'blather', 'blether', 'blither', 'smatter'],
#  '02187922': ['babble', 'bubble', 'burble', 'guggle', 'gurgle', 'ripple'],
#  '00937208': ['babble',
#   'babble_out',
#   'blab',
#   'blab_out',
#   'let_the_cat_out_of_the_bag',
#   'peach',
#   'sing',
#   'spill_the_beans',
#   'talk',
#   'tattle'],
#  '02570267': ['baby',
#   'cocker',
#   'coddle',
#   'cosset',
#   'featherbed',
#   'indulge',
#   'mollycoddle',
#   'pamper',
#   'spoil'],
#  '02602898': ['baby-sit'],
#  '02456270': ['baby-sit', 'sit'],
#  '02616118': ['bach', 'bachelor'],
#  '02453889': ['back',
#   'endorse',
#   'indorse',
#   'plump_for',
#   'plunk_for',
#   'support'],
#  '01997119': ['back', 'cyclops', 'water_flea'],
#  '02556817': ['back', 'endorse', 'indorse', 'second'],
#  '01997512': ['back'],
#  '02217695': ['back'],
#  '02693965': ['back'],
#  '01139104': ['back', 'bet_on', 'gage', 'game', 'punt', 'stake'],
#  '00560628': ['back'],
#  '00223109': ['back', 'back_up'],
#  '00185857': ['back'],
#  '00799383': ['back_away',
#   'back_out',
#   'crawfish',
#   'crawfish_out',
#   'pull_back',
#   "pull_in_one's_horns",
#   'retreat',
#   'withdraw'],
#  '01997680': ['back_down', 'back_off', 'back_up'],
#  '02380980': ['back_down', 'back_off', 'bow_out', 'chicken_out', 'pull_out'],
#  '01997376': ['back_out'],
#  '02556126': ['back_up', 'support'],
#  '01694620': ['back_up'],
#  '01478603': ['back_up',
#   'choke',
#   'choke_off',
#   'clog',
#   'clog_up',
#   'congest',
#   'foul'],
#  '00907657': ['backbite', 'bitch'],
#  '01429825': ['backcross'],
#  '02561846': ['backdate'],
#  '02378950': ['backfire', 'backlash', 'recoil'],
#  '02173663': ['backfire'],
#  '00379023': ['backfire'],
#  '00513492': ['background', 'downplay', 'play_down'],
#  '01404664': ['backhand'],
#  '00159236': ['backlog'],
#  '01926031': ['backpack', 'pack'],
#  '01935953': ['backpedal'],
#  '01929041': ['backpedal'],
#  '00688960': ['backpedal'],
#  '00330751': ['backscatter'],
#  '02374572': ['backslap'],
#  '00204585': ['backslide', 'lapse'],
#  '01005373': ['backspace'],
#  '01330567': ['backstitch'],
#  '01076130': ['backstop'],
#  '01962375': ['backstroke'],
#  '02004528': ['backtrack', 'double_back', 'turn_back'],
#  '00138360': ['bacterise', 'bacterize'],
#  '01589869': ['badge'],
#  '01803380': ['badger', 'beleaguer', 'bug', 'pester', 'tease'],
#  '00767530': ['badger'],
#  '00848169': ['badmouth', 'drag_through_the_mud', 'malign', 'traduce'],
#  '02558172': ['baffle',
#   'bilk',
#   'cross',
#   'foil',
#   'frustrate',
#   'queer',
#   'scotch',
#   'spoil',
#   'thwart'],
#  '00234988': ['baffle', 'regulate'],
#  '01479874': ['bag'],
#  '02717362': ['bag'],
#  '02714360': ['bag', 'bulge'],
#  '02292432': ['bag', 'pocket'],
#  '01485839': ['bag'],
#  '02421749': ['bail'],
#  '02293732': ['bail'],
#  '00890403': ['bail'],
#  '00177136': ['bail'],
#  '00177011': ['bail'],
#  '02494259': ['bail_out'],
#  '00449426': ['bail_out', 'bale_out'],
#  '00850501': ['bait',
#   'cod',
#   'rag',
#   'rally',
#   'razz',
#   'ride',
#   'tantalise',
#   'tantalize',
#   'taunt',
#   'tease',
#   'twit'],
#  '02577877': ['bait'],
#  '01114911': ['bait'],
#  '00319886': ['bake'],
#  '01663749': ['bake'],
#  '00544136': ['bake', 'broil'],
#  '02755565': ['bake', 'broil'],
#  '02673134': ['balance', 'equilibrate', 'equilibrise', 'equilibrize'],
#  '02264967': ['balance'],
#  '01602318': ['balance', 'poise'],
#  '02743020': ['balance'],
#  '00126143': ['bald'],
#  '01386200': ['bale'],
#  '02583545': ['balk', 'baulk', 'jib', 'resist'],
#  '02469711': ['balkanise', 'balkanize'],
#  '01523270': ['ball'],
#  '01809064': ['ball_over',
#   'blow_out_of_the_water',
#   'floor',
#   'shock',
#   'take_aback'],
#  '02527651': ['ball_up',
#   'blow',
#   'bobble',
#   'bodge',
#   'bollix',
#   'bollix_up',
#   'bollocks',
#   'bollocks_up',
#   'botch',
#   'botch_up',
#   'bumble',
#   'bungle',
#   'flub',
#   'fluff',
#   'foul_up',
#   'fuck_up',
#   'fumble',
#   'louse_up',
#   'mess_up',
#   'mishandle',
#   'muck_up',
#   'muff',
#   'screw_up',
#   'spoil'],
#  '00271403': ['ballast'],
#  '01948659': ['balloon'],
#  '00256117': ['balloon', 'billow', 'inflate'],
#  '02463141': ['ballot'],
#  '00976365': ['ballyhoo'],
#  '01781520': ['ballyrag',
#   'boss_around',
#   'browbeat',
#   'bully',
#   'bullyrag',
#   'hector',
#   'push_around',
#   'strong-arm'],
#  '00839194': ['bamboozle',
#   'hoodwink',
#   'lead_by_the_nose',
#   'play_false',
#   "pull_the_wool_over_someone's_eyes",
#   'snow'],
#  '02493666': ['ban', 'censor'],
#  '00796392': ['ban'],
#  '02504280': ['ban', 'banish'],
#  '02504017': ['ban',
#   'banish',
#   'blackball',
#   'cast_out',
#   'ostracise',
#   'ostracize',
#   'shun'],
#  '01304342': ['band'],
#  '01297401': ['band', 'ring'],
#  '02430078': ['band_oneself', 'league_together'],
#  '02470685': ['band_together', 'confederate'],
#  '01303547': ['bandage', 'bind'],
#  '00083124': ['bandage'],
#  '01147296': ['bandy'],
#  '01138446': ['bandy'],
#  '00813651': ['bandy', 'kick_around'],
#  '00970107': ['bandy_about'],
#  '01242391': ['bang', 'slam'],
#  '02187693': ['bang'],
#  '01242832': ['bang', 'slam'],
#  '02100176': ['bang'],
#  '01426397': ['bang',
#   'be_intimate',
#   'bed',
#   'bonk',
#   'do_it',
#   'eff',
#   'fuck',
#   'get_it_on',
#   'get_laid',
#   'have_a_go_at_it',
#   'have_intercourse',
#   'have_it_away',
#   'have_it_off',
#   'have_sex',
#   'hump',
#   'jazz',
#   'know',
#   'lie_with',
#   'love',
#   'make_love',
#   'make_out',
#   'roll_in_the_hay',
#   'screw',
#   'sleep_together',
#   'sleep_with'],
#  '01236941': ['bang', 'spang'],
#  '01728213': ['bang_out'],
#  '01566705': ['bang_up', 'smash', 'smash_up'],
#  '00053159': ['bang_up', 'impregnate', 'knock_up', 'prang_up'],
#  '02503803': ['banish', 'bar', 'relegate'],
#  '02003359': ['banish'],
#  '02039413': ['bank'],
#  '01587705': ['bank'],
#  '02343374': ['bank'],
#  '02343252': ['bank'],
#  '02343056': ['bank'],
#  '02310855': ['bank', 'deposit'],
#  '01234793': ['bank'],
#  '00688377': ['bank', 'rely', 'swear', 'trust'],
#  '02216384': ['bankroll'],
#  '02318165': ['bankrupt', 'break', 'ruin', 'smash'],
#  '01186208': ['banquet', 'feast', 'junket'],
#  '01185981': ['banquet', 'feast', 'junket', 'reversal'],
#  '00855295': ['banter', 'chaff', 'jolly', 'josh', 'kid'],
#  '01028079': ['baptise', 'baptize', 'christen'],
#  '00796588': ['bar', 'debar', 'exclude'],
#  '01478002': ['bar',
#   'barricade',
#   'block',
#   'block_off',
#   'block_up',
#   'blockade',
#   'stop'],
#  '01342910': ['bar'],
#  '01171941': ['bar_hop', 'pub-crawl'],
#  '02474958': ['bar_mitzvah'],
#  '01339181': ['barb'],
#  '00134564': ['barbarise', 'barbarize'],
#  '00134328': ['barbarise', 'barbarize'],
#  '00324806': ['barbecue', 'barbeque', 'cook_out'],
#  '00042792': ['barber'],
#  '01670315': ['bard', 'barde', 'caparison', 'dress_up'],
#  '01340028': ['bare'],
#  '00194912': ['bare', 'denudate', 'denude', 'strip'],
#  '00076400': ['barf',
#   'be_sick',
#   'cast',
#   'cat',
#   'chuck',
#   'disgorge',
#   'honk',
#   'puke',
#   'purge',
#   'regorge',
#   'regurgitate',
#   'retch',
#   'sick',
#   'spew',
#   'spue',
#   'throw_up',
#   'upchuck',
#   'vomit',
#   'vomit_up'],
#  ...}

# %%
def list_synonyms(lemma):
    lemma = lemma.lower()
    synonyms = []
    synsets = lemma_synset_map[lemma]
    for synset in synsets:
        synonyms.extend(synset_lemma_map[synset])
    return list(set(synonyms))

# %%
list_synonyms("hello")
# Out:
# ['hi', 'hello', 'hullo', 'how-do-you-do', 'howdy']

# %%
datadf
# Out:
#       synset_offset lex_filenum ss_type w_cnt  \
# 0          00001740          03       n    01
# 1          00001930          03       n    01
# 2          00002137          03       n    02
# 3          00002452          03       n    01
# 4          00002684          03       n    02
# ...             ...         ...     ...   ...
# 82110      15299225          28       n    01
# 82111      15299367          28       n    03
# 82112      15299585          28       n    01
# 82113      15299783          28       n    01
# 82114      15300051          28       n    05
#
#                                         word with lex_id p_cnt  \
# 0                                          [[entity, 0]]   003
# 1                                 [[physical_entity, 0]]   007
# 2               [[abstraction, 0], [abstract_entity, 0]]   010
# 3                                           [[thing, 0]]   009
# 4                    [[object, 0], [physical_object, 0]]   039
# ...                                                  ...   ...
# 82110                                  [[study_hall, 0]]   002
# 82111  [[Transfiguration, 0], [Transfiguration_Day, 0...   003
# 82112                                      [[usance, 0]]   002
# 82113                                      [[window, 0]]   001
# 82114  [[9/11, 0], [9-11, 0], [September_11, 0], [Sep...   003
#
#                                                      ptr  \
# 0      [[~, 00001930, n, 0000], [~, 00002137, n, 0000...
# 1      [[@, 00001740, n, 0000], [~, 00002452, n, 0000...
# 2      [[@, 00001740, n, 0000], [+, 00692329, v, 0101...
# 3      [[@, 00001930, n, 0000], [~, 04347225, n, 0000...
# 4      [[@, 00001930, n, 0000], [+, 00532607, v, 0105...
# ...                                                  ...
# 82110  [[@, 15113229, n, 0000], [#p, 15203229, n, 0000]]
# 82111  [[@, 15184170, n, 0000], [;c, 06226057, n, 000...
# 82112  [[@, 15113229, n, 0000], [;c, 01090446, n, 0000]]
# 82113                           [[@, 15113229, n, 0000]]
# 82114  [[#p, 15212739, n, 0000], [@i, 01246697, n, 00...
#
#                                                    gloss
# 0      that which is perceived or known or inferred t...
# 1                  an entity that has physical existence
# 2      a general concept formed by extracting common ...
# 3                   a separate and self-contained entity
# 4      a tangible and visible entity; an entity that ...
# ...                                                  ...
# 82110  a period of time during the school day that is...
# 82111  (Christianity) a church festival held in comme...
# 82112  the period of time permitted by commercial usa...
# 82113  the time period that is considered best for st...
# 82114  the day in 2001 when Arab suicide bombers hija...
#
# [82115 rows x 8 columns]

# %%
synset_offset = datadf['synset_offset'].to_list()
words = datadf['word with lex_id'].to_list()
words = datadf['word with lex_id'].to_list()

# %%
words
# Out:
# [[['entity', '0']],
#  [['physical_entity', '0']],
#  [['abstraction', '0'], ['abstract_entity', '0']],
#  [['thing', '0']],
#  [['object', '0'], ['physical_object', '0']],
#  [['whole', '0'], ['unit', '0']],
#  [['congener', '0']],
#  [['living_thing', '0'], ['animate_thing', '0']],
#  [['organism', '0'], ['being', '0']],
#  [['benthos', '0']],
#  [['dwarf', '0']],
#  [['heterotroph', '0']],
#  [['parent', '0']],
#  [['life', '0']],
#  [['biont', '0']],
#  [['cell', '0']],
#  [['causal_agent', '0'], ['cause', '0'], ['causal_agency', '0']],
#  [['person', '0'],
#   ['individual', '0'],
#   ['someone', '0'],
#   ['somebody', '0'],
#   ['mortal', '0'],
#   ['soul', '0']],
#  [['animal', '0'],
#   ['animate_being', '0'],
#   ['beast', '0'],
#   ['brute', '0'],
#   ['creature', '0'],
#   ['fauna', '0']],
#  [['plant', '0'], ['flora', '0'], ['plant_life', '0']],
#  [['native', '0']],
#  [['natural_object', '0']],
#  [['substance', '0']],
#  [['substance', '1']],
#  [['matter', '0']],
#  [['food', '0'], ['nutrient', '0']],
#  [['nutrient', '1']],
#  [['artifact', '0'], ['artefact', '0']],
#  [['article', '0']],
#  [['psychological_feature', '0']],
#  [['cognition', '0'], ['knowledge', '0'], ['noesis', '0']],
#  [['motivation', '0'], ['motive', '0'], ['need', '0']],
#  [['attribute', '0']],
#  [['state', '0']],
#  [['feeling', '0']],
#  [['location', '0']],
#  [['shape', '0'], ['form', '0']],
#  [['time', '0']],
#  [['space', '0'], ['infinite', '0']],
#  [['absolute_space', '0']],
#  [['phase_space', '0']],
#  [['event', '0']],
#  [['process', '0'], ['physical_process', '0']],
#  [['act', '0'], ['deed', '0'], ['human_action', '0'], ['human_activity', '0']],
#  [['group', '0'], ['grouping', '0']],
#  [['relation', '0']],
#  [['possession', '0']],
#  [['social_relation', '0']],
#  [['communication', '0']],
#  [['measure', '0'], ['quantity', '0'], ['amount', '0']],
#  [['phenomenon', '0']],
#  [['thing', '0']],
#  [['kindness', '0'], ['benignity', '0']],
#  [['abdominoplasty', '0'], ['tummy_tuck', '0']],
#  [['abort', '0']],
#  [['accomplishment', '0'], ['achievement', '0']],
#  [['agon', '0']],
#  [['alienation', '0']],
#  [['application', '0']],
#  [['beachhead', '0'], ['foothold', '0']],
#  [['cakewalk', '1']],
#  [['feat', '0'], ['effort', '2'], ['exploit', '0']],
#  [['masterpiece', '0']],
#  [['masterstroke', '0']],
#  [['credit', '1']],
#  [['action', '2']],
#  [['res_gestae', '0']],
#  [['course', '0'], ['course_of_action', '0']],
#  [['blind_alley', '0']],
#  [['collision_course', '0']],
#  [['interaction', '0']],
#  [['interplay', '0']],
#  [['contact', '2']],
#  [['brush', '4']],
#  [['eye_contact', '0']],
#  [['fetch', '0']],
#  [['placement', '1']],
#  [['interchange', '1'], ['reciprocation', '2'], ['give-and-take', '0']],
#  [['reciprocity', '0']],
#  [['cross-fertilization', '0'], ['cross-fertilisation', '0']],
#  [['dealings', '2'], ['traffic', '2']],
#  [['relation', '0']],
#  [['playing', '0']],
#  [['play', '7'], ['swordplay', '0']],
#  [['boondoggle', '0']],
#  [['bowling', '1']],
#  [['acquiring', '0'], ['getting', '0']],
#  [['causing', '0'], ['causation', '0']],
#  [['delivery', '2'], ['obstetrical_delivery', '0']],
#  [['departure', '0'], ['going', '1'], ['going_away', '0'], ['leaving', '0']],
#  [['derring-do', '0']],
#  [['discovery', '0'], ['find', '0'], ['uncovering', '0']],
#  [['disposal', '0'], ['disposition', '0']],
#  [['hit', '3']],
#  [['implementation', '0'], ['effectuation', '0']],
#  [['egress', '1'], ['egression', '0'], ['emergence', '0']],
#  [['equalization', '0'], ['equalisation', '0'], ['leveling', '0']],
#  [['exhumation', '0'], ['disinterment', '0'], ['digging_up', '0']],
#  [['mitzvah', '0'], ['mitsvah', '0']],
#  [['propulsion', '0'], ['actuation', '0']],
#  [['rally', '1'], ['rallying', '1']],
#  [['recovery', '0'], ['retrieval', '0']],
#  [['running_away', '0']],
#  [['stunt', '0']],
#  [['touch', '0'], ['touching', '0']],
#  [['tour_de_force', '0']],
#  [['performance', '3']],
#  [['overachievement', '0']],
#  [['underachievement', '0']],
#  [['record', '1'], ['track_record', '1']],
#  [['fait_accompli', '0'], ['accomplished_fact', '0']],
#  [['going', '0'], ['sledding', '1']],
#  [['arrival', '0'], ['reaching', '0']],
#  [['arrival', '1']],
#  [['attainment', '1']],
#  [['advent', '0'], ['coming', '1']],
#  [['entrance', '0'],
#   ['entering', '0'],
#   ['entry', '0'],
#   ['ingress', '0'],
#   ['incoming', '0']],
#  [['incursion', '1']],
#  [['intrusion', '2']],
#  [['irruption', '0']],
#  [['entree', '0']],
#  [['entail', '0']],
#  [['registration', '0'], ['enrollment', '0'], ['enrolment', '0']],
#  [['appearance', '0']],
#  [['apparition', '0']],
#  [['emergence', '1'], ['emersion', '1']],
#  [['reappearance', '0'], ['return', '7']],
#  [['comeback', '0']],
#  [['return', '1'], ['homecoming', '0']],
#  [['repatriation', '0']],
#  [['penetration', '2']],
#  [['interpenetration', '0'], ['permeation', '0']],
#  [['market_penetration', '0']],
#  [['anchorage', '0']],
#  [['docking', '0'], ['moorage', '0'], ['dockage', '0'], ['tying_up', '0']],
#  [['landing', '0']],
#  [['landing', '1']],
#  [['forced_landing', '0'], ['emergency_landing', '1']],
#  [['breaking_away', '0']],
#  [['farewell', '0'], ['leave', '0'], ['leave-taking', '0'], ['parting', '0']],
#  [['French_leave', '0']],
#  [['valediction', '0']],
#  [['disappearance', '0'], ['disappearing', '0']],
#  [['vanishing', '0']],
#  [['withdrawal', '0']],
#  [['effacement', '0'], ['self-effacement', '0']],
#  [['retreat', '2']],
#  [['retirement', '1'], ['retreat', '1']],
#  [['evacuation', '1']],
#  [['medical_evacuation', '0'], ['medevac', '0'], ['medivac', '0']],
#  [['decampment', '0']],
#  [['desertion', '0'], ['abandonment', '1'], ['defection', '0']],
#  [['abscondment', '0'], ['decampment', '1']],
#  [['absence_without_leave', '0'], ['unauthorized_absence', '0']],
#  [['deviationism', '0']],
#  [['emigration', '0'], ['out-migration', '0'], ['expatriation', '1']],
#  [['immigration', '0'], ['in-migration', '0']],
#  [['aliyah', '0']],
#  [['pullback', '0']],
#  [['retreat', '0']],
#  [['standdown', '0'], ['stand-down', '0']],
#  [['disengagement', '0'], ['fallback', '0'], ['pullout', '0']],
#  [['receding', '0'], ['recession', '0']],
#  [['sailing', '2']],
#  [['amphibious_landing', '0']],
#  [['debarkation', '0'], ['disembarkation', '0'], ['disembarkment', '0']],
#  [['going_ashore', '0']],
#  [['boarding', '0'], ['embarkation', '0'], ['embarkment', '0']],
#  [['exit', '0']],
#  [['elopement', '0']],
#  [['escape', '0'], ['flight', '1']],
#  [['evasion', '0']],
#  [['slip', '3'], ['elusion', '0'], ['eluding', '0']],
#  [['maneuver', '1'], ['manoeuvre', '1'], ['evasive_action', '0']],
#  [['clinch', '0']],
#  [['dodge', '0']],
#  [['break', '4'],
#   ['breakout', '0'],
#   ['jailbreak', '0'],
#   ['gaolbreak', '0'],
#   ['prisonbreak', '0'],
#   ['prison-breaking', '0']],
#  [['getaway', '0'], ['lam', '0']],
#  [['exodus', '0'], ['hegira', '0'], ['hejira', '0']],
#  [['Hegira', '1'], ['Hejira', '1']],
#  [['skedaddle', '0']],
#  [['Underground_Railroad', '0'], ['Underground_Railway', '0']],
#  [['close_call', '0'],
#   ['close_shave', '0'],
#   ['squeak', '0'],
#   ['squeaker', '0'],
#   ['narrow_escape', '0']],
#  [['surfacing', '0']],
#  [['dispatch', '0'], ['despatch', '0'], ['shipment', '0']],
#  [['reshipment', '0']],
#  [['consummation', '0']],
#  [['consummation', '1']],
#  [['realization', '2'], ['realisation', '2'], ['fruition', '0']],
#  [['orgasm', '0'], ['climax', '0'], ['sexual_climax', '0'], ['coming', '0']],
#  [['male_orgasm', '0']],
#  [['fulfillment', '0'], ['fulfilment', '0']],
#  [['self-fulfillment', '0'],
#   ['self-realization', '0'],
#   ['self-realisation', '0']],
#  [['attainment', '0']],
#  [['record', '0']],
#  [['track_record', '0']],
#  [['world_record', '0']],
#  [['success', '0']],
#  [['winning', '0']],
#  [['blockbuster', '0'], ['megahit', '0'], ['smash_hit', '0']],
#  [['sleeper', '0']],
#  [['hit', '2'],
#   ['smash', '1'],
#   ['smasher', '0'],
#   ['strike', '3'],
#   ['bang', '0']],
#  [['bell_ringer', '0'], ["bull's_eye", '1'], ['mark', '1'], ['home_run', '1']],
#  [['ennoblement', '0']],
#  [['conquest', '0']],
#  [['coup', '1']],
#  [['flying_colors', '0'], ['flying_colours', '0']],
#  [['passing', '2'], ['pass', '5'], ['qualifying', '0']],
#  [['credit', '0'], ['course_credit', '0']],
#  [['semester_hour', '0'], ['credit_hour', '0']],
#  [['nonaccomplishment', '0'], ['nonachievement', '0']],
#  [['failure', '1']],
#  [['failure', '0']],
#  [['failing', '0'], ['flunk', '0']],
#  [['naught', '0']],
#  [['cut', '6']],
#  [['default', '0']],
#  [['loss', '0']],
#  [['capitulation', '0'], ['fall', '2'], ['surrender', '0']],
#  [['frustration', '2'], ['thwarting', '0'], ['foiling', '0']],
#  [['overturn', '1'], ['upset', '0']],
#  [['backsliding', '0'],
#   ['lapse', '1'],
#   ['lapsing', '0'],
#   ['relapse', '0'],
#   ['relapsing', '0'],
#   ['reversion', '0'],
#   ['reverting', '0']],
#  [['recidivism', '0']],
#  [['disappointment', '0'], ['dashing_hopes', '0']],
#  [['breach', '1']],
#  [['copout', '0']],
#  [['breach_of_contract', '0']],
#  [['anticipatory_breach', '0'], ['constructive_breach', '0']],
#  [['breach_of_duty', '0']],
#  [['breach_of_the_covenant_of_warranty', '0']],
#  [['breach_of_promise', '0']],
#  [['breach_of_trust', '0']],
#  [['breach_of_trust_with_fraudulent_intent', '0']],
#  [['breach_of_warranty', '0']],
#  [['leaning', '0']],
#  [['material_breach', '0']],
#  [['motivation', '0'], ['motivating', '0']],
#  [['partial_breach', '0']],
#  [['mistake', '0'], ['error', '2'], ['fault', '0']],
#  [['double_fault', '0']],
#  [['footfault', '0']],
#  [['bobble', '0']],
#  [['error', '3'], ['misplay', '0']],
#  [['blot', '0'],
#   ['smear', '0'],
#   ['smirch', '0'],
#   ['spot', '0'],
#   ['stain', '0']],
#  [['confusion', '0'], ['mix-up', '0']],
#  [['incursion', '2']],
#  [['miscalculation', '0'], ['misreckoning', '0'], ['misestimation', '0']],
#  [['backfire', '0'], ['boomerang', '0']],
#  [['rounding', '0'], ['rounding_error', '0']],
#  [['truncation_error', '0']],
#  [['distortion', '1']],
#  [['slip', '5'], ['slip-up', '1'], ['miscue', '1'], ['parapraxis', '0']],
#  [['Freudian_slip', '0']],
#  [['offside', '0']],
#  [['oversight', '0'], ['lapse', '0']],
#  [['omission', '1'], ['skip', '0']],
#  [['blunder', '0'],
#   ['blooper', '0'],
#   ['bloomer', '0'],
#   ['bungle', '0'],
#   ['pratfall', '0'],
#   ['foul-up', '0'],
#   ['fuckup', '0'],
#   ['flub', '0'],
#   ['botch', '0'],
#   ['boner', '0'],
#   ['boo-boo', '0']],
#  [['snafu', '0']],
#  [['spectacle', '0']],
#  [['ballup', '0'], ['balls-up', '0'], ['cockup', '0'], ['mess-up', '0']],
#  [['bull', '0']],
#  [['fumble', '0'], ['muff', '0']],
#  [['fluff', '0']],
#  [['faux_pas', '0'],
#   ['gaffe', '0'],
#   ['solecism', '0'],
#   ['slip', '2'],
#   ['gaucherie', '0']],
#  [['howler', '0']],
#  [['clanger', '0']],
#  [['trip', '1'], ['trip-up', '0'], ['stumble', '1'], ['misstep', '0']],
#  [['spill', '1'], ['tumble', '1'], ['fall', '1']],
#  [['pratfall', '1']],
#  [['wipeout', '0']],
#  [['acquisition', '0']],
#  [['obtainment', '0'], ['obtention', '0']],
#  [['catching', '2'], ['contracting', '0']],
#  [['incurring', '0']],
#  [['moneymaking', '0']],
#  [['annexation', '0']],
#  [['pork-barreling', '0']],
#  [['purchase', '0']],
#  [['redemption', '0'], ['repurchase', '0'], ['buyback', '0']],
#  [['trading', '0']],
#  [['bond_trading', '0'], ['bond-trading_activity', '0']],
#  [['program_trading', '0']],
#  [['short_sale', '0'], ['short_selling', '0']],
#  [['short_covering', '0']],
#  [['insider_trading', '0']],
#  [['naked_option', '0']],
#  [['covered_option', '0']],
#  [['call_option', '0'], ['call', '4']],
#  [['put_option', '0'], ['put', '0']],
#  [['straddle', '1']],
#  [['incentive_option', '0'], ['incentive_stock_option', '0']],
#  [['buying', '0'], ['purchasing', '0']],
#  [['shopping', '0']],
#  [['marketing', '1']],
#  [['mail-order_buying', '0'], ['catalog_buying', '0']],
#  [['viatication', '0'], ['viaticus', '0']],
#  [['acceptance', '3']],
#  [['succession', '1'], ['taking_over', '0']],
#  [['assumption', '0'], ['laying_claim', '0']],
#  [['assumption', '1']],
#  [['position', '4']],
#  [['inheritance', '0'], ['heritage', '0']],
#  [['procurement', '0'], ['procurance', '0'], ['procural', '0']],
#  [['appropriation', '0']],
#  [['borrowing', '1'], ['adoption', '1']],
#  [['naturalization', '1'], ['naturalisation', '1']],
#  [['misappropriation', '2']],
#  [['preemption', '0'], ['pre-emption', '0']],
#  [['seizure', '0']],
#  [['usurpation', '0']],
#  [['confiscation', '0'], ['arrogation', '0']],
#  [['distress', '0'], ['distraint', '0']],
#  [['expropriation', '0']],
#  [['impoundment', '0'],
#   ['impounding', '0'],
#   ['internment', '1'],
#   ['poundage', '0']],
#  [['drug_bust', '0'], ['drugs_bust', '0']],
#  [['impress', '0'], ['impressment', '0']],
#  [['occupation', '1'], ['occupancy', '1'], ['moving_in', '0']],
#  [['preoccupancy', '0'], ['preoccupation', '0']],
#  [['sequestration', '1'], ['requisition', '1']],
#  [['grant', '0'], ['subsidization', '0'], ['subsidisation', '0']],
#  [['award', '0'], ['awarding', '0']],
#  [['addiction', '0']],
#  [['block_grant', '0']],
#  [['grant-in-aid', '0']],
#  [['capture', '0'], ['gaining_control', '0'], ['seizure', '1']],
#  [['apprehension', '0'],
#   ['arrest', '0'],
#   ['catch', '1'],
#   ['collar', '0'],
#   ['pinch', '1'],
#   ['taking_into_custody', '0']],
#  [['conquest', '1'],
#   ['conquering', '0'],
#   ['subjection', '0'],
#   ['subjugation', '0']],
#  [['enslavement', '0']],
#  [['restitution', '0'],
#   ['return', '2'],
#   ['restoration', '1'],
#   ['regaining', '0']],
#  [['clawback', '0']],
#  [['repossession', '0']],
#  [['foreclosure', '0']],
#  [['reception', '0'], ['receipt', '0']],
#  [['appointment', '2']],
#  [['comb-out', '1']],
#  [['giving', '1']],
#  [['abandonment', '2']],
#  [['discard', '0'], ['throwing_away', '0']],
#  [['staging', '1']],
#  [['discard', '1']],
#  [['mine_disposal', '0']],
#  [['minesweeping', '0']],
#  [['sewage_disposal', '0']],
#  [['bait_and_switch', '0']],
#  [['private_treaty', '0']],
#  [['auction', '0'], ['auction_sale', '0'], ['vendue', '0']],
#  [['bootlegging', '0']],
#  [['bootlegging', '1']],
#  [['capitalization', '2'], ['capitalisation', '2']],
#  [['overcapitalization', '0'], ['overcapitalisation', '0']],
#  [['reclamation', '2']],
#  [['rescue', '0'], ['deliverance', '0'], ['delivery', '0'], ['saving', '2']],
#  [['lifesaving', '0']],
#  [['redemption', '1'], ['salvation', '0']],
#  [['absolution', '0'],
#   ['remission', '0'],
#   ['remittal', '0'],
#   ['remission_of_sin', '0']],
#  [['indulgence', '2']],
#  [['conversion', '1'], ['rebirth', '0'], ['spiritual_rebirth', '0']],
#  [['proselytism', '0']],
#  [['expiation', '0'], ['atonement', '0'], ['propitiation', '1']],
#  [['reparation', '0'], ['amends', '0']],
#  [['liberation', '2'], ['release', '1'], ['freeing', '0']],
#  [['jail_delivery', '0']],
#  [['reclamation', '0'], ['reformation', '1']],
#  [['salvage', '0']],
#  [['salvage', '1']],
#  [['salvation', '2']],
#  [['search_and_rescue_mission', '0']],
#  [['ransom', '0']],
#  [['recapture', '0'], ['retaking', '0']],
#  [['recapture', '1']],
#  [['invocation', '1']],
#  [['instrumentation', '0']],
#  [['performance', '0'],
#   ['execution', '2'],
#   ['carrying_out', '1'],
#   ['carrying_into_action', '0']],
#  [['specific_performance', '0']],
#  [['linguistic_performance', '0']],
#  [['mechanism', '0'], ['mechanics', '0']],
#  [['service', '6']],
#  [['curb_service', '0']],
#  [['self-service', '0']],
#  [['valet_parking', '0']],
#  [['dramatic_production', '0'], ['dramatic_performance', '0']],
#  [['encore', '0']],
#  [['extemporization', '0'], ['extemporisation', '0'], ['improvisation', '1']],
#  [['juggle', '0'], ['juggling', '0']],
#  [['magic_trick', '0'],
#   ['conjuring_trick', '0'],
#   ['trick', '2'],
#   ['magic', '1'],
#   ['legerdemain', '0'],
#   ['conjuration', '0'],
#   ['thaumaturgy', '0'],
#   ['illusion', '2'],
#   ['deception', '1']],
#  [['musical_performance', '0']],
#  [['one-night_stand', '0']],
#  [['rendition', '1'], ['rendering', '1'], ['interpretation', '2']],
#  [['reinterpretation', '0']],
#  [['spin', '3']],
#  [['playing', '1']],
#  [['bowing', '0']],
#  [['spiccato', '0'], ['spiccato_bowing', '0']],
#  [['piping', '0']],
#  [['stopping', '0']],
#  [['double_stopping', '0']],
#  [['transposition', '1']],
#  [['jam_session', '0']],
#  [['automation', '0'], ['mechanization', '0'], ['mechanisation', '0']],
#  [['computerization', '0'], ['cybernation', '0']],
#  [['motorization', '0'], ['motorisation', '0']],
#  [['launching', '0'], ['launch', '0']],
#  [['launching', '2']],
#  [['rocket_firing', '0'], ['rocket_launching', '0']],
#  [['blastoff', '0'], ['shot', '7']],
#  [['moon_shot', '0']],
#  [['drive', '4'], ['thrust', '0'], ['driving_force', '0']],
#  [['firewall', '0']],
#  [['impulse', '1'], ['impulsion', '0'], ['impetus', '0']],
#  [['roll', '2'], ['bowl', '0']],
#  [['throw', '0']],
#  [['bowling', '2']],
#  [['fling', '2']],
#  [['heave', '0'], ['heaving', '0']],
#  [['hurl', '0'], ['cast', '3']],
#  [['leaner', '0']],
#  [['pass', '0'], ['toss', '0'], ['flip', '0']],
#  [['pitch', '0']],
#  [['pitch', '3'], ['delivery', '3']],
#  [['ringer', '0']],
#  [['shy', '0']],
#  [['slinging', '0']],
#  [['throw-in', '0']],
#  [['balk', '0']],
#  [['ball', '0']],
#  [['beanball', '0'], ['beaner', '0']],
#  [['change-up', '0'],
#   ['change-of-pace', '0'],
#   ['change-of-pace_ball', '0'],
#   ['off-speed_pitch', '0']],
#  [['curve', '2'],
#   ['curve_ball', '0'],
#   ['breaking_ball', '0'],
#   ['bender', '2']],
#  [['duster', '0']],
#  [['fastball', '0'],
#   ['heater', '0'],
#   ['smoke', '2'],
#   ['hummer', '0'],
#   ['bullet', '0']],
#  [['knuckleball', '0'], ['knuckler', '0']],
#  [['overhand_pitch', '0']],
#  [['passed_ball', '0']],
#  [['screwball', '0']],
#  [['sinker', '0']],
#  [['slider', '0']],
#  [['spitball', '0'], ['spitter', '0']],
#  [['strike', '5']],
#  [['submarine_ball', '0'], ['submarine_pitch', '0']],
#  [['wild_pitch', '0']],
#  [['basketball_shot', '0']],
#  [['bank_shot', '0']],
#  [['dunk', '0'], ['dunk_shot', '0'], ['stuff_shot', '0']],
#  [['slam_dunk', '0']],
#  [['finger-roll', '0']],
#  [['foul_shot', '0'],
#   ['free_throw', '0'],
#   ['penalty_free_throw', '0'],
#   ['charity_toss', '0'],
#   ['charity_throw', '0'],
#   ['charity_shot', '0']],
#  [['one-and-one', '0']],
#  [['hook_shot', '0'], ['hook', '3']],
#  [['jumper', '0'], ['jump_shot', '0']],
#  [['lay-up', '0'], ['layup', '0']],
#  [['pivot_shot', '0']],
#  [['set_shot', '0']],
#  [['scoop_shot', '0']],
#  [['tip_in', '0']],
#  [['push', '0'], ['pushing', '0']],
#  [['depression', '1']],
#  [['click', '0'], ['mouse_click', '0']],
#  [['nudge', '0'], ['jog', '1']],
#  [['press', '0'], ['pressure', '0'], ['pressing', '0']],
#  [['impression', '1']],
#  [['shove', '0']],
#  [['bundling', '1']],
#  [['jostle', '0'], ['jostling', '0']],
#  [['elbowing', '0']],
#  [['pull', '0'], ['pulling', '0']],
#  [['drag', '0']],
#  [['draw', '0'], ['haul', '0'], ['haulage', '0']],
#  [['tow', '0'], ['towage', '0']],
#  [['tug', '0'], ['jerk', '1']],
#  [['draft', '0'], ['draught', '0'], ['drawing', '4']],
#  [['extirpation', '1'], ['excision', '1'], ['deracination', '0']],
#  [['pluck', '0']],
#  [['traction', '0']],
#  [['lift', '0'], ['raise', '0'], ['heave', '2']],
#  [['expulsion', '0'],
#   ['projection', '0'],
#   ['ejection', '1'],
#   ['forcing_out', '0']],
#  [['defenestration', '0']],
#  [['accommodation_reflex', '0']],
#  [['Babinski', '0'], ['Babinski_reflex', '0'], ['Babinski_sign', '0']],
#  [['belch', '0'],
#   ['belching', '0'],
#   ['burp', '0'],
#   ['burping', '0'],
#   ['eructation', '0']],
#  [['belching', '1']],
#  [['blink', '0'],
#   ['eye_blink', '0'],
#   ['blinking', '0'],
#   ['wink', '0'],
#   ['winking', '0'],
#   ['nictitation', '0'],
#   ['nictation', '0']],
#  [['blush', '0'], ['flush', '0']],
#  [['coughing_up', '0']],
#  [['spit', '0'], ['spitting', '0'], ['expectoration', '0']],
#  [['vomit', '0'],
#   ['vomiting', '0'],
#   ['emesis', '0'],
#   ['regurgitation', '0'],
#   ['disgorgement', '0'],
#   ['puking', '0']],
#  [['rumination', '0']],
#  [['hematemesis', '0'], ['haematemesis', '0']],
#  [['hyperemesis', '0']],
#  [['hyperemesis_gravidarum', '0']],
#  [['jump', '0'], ['jumping', '1']],
#  [['header', '1']],
#  [['hop', '0']],
#  [['leap', '0'],
#   ['leaping', '0'],
#   ['spring', '0'],
#   ['saltation', '0'],
#   ['bound', '0'],
#   ['bounce', '0']],
#  [['vault', '0'], ['hurdle', '0']],
#  [['jumping_up_and_down', '0']],
#  [['lob', '0']],
#  [['centering', '0'], ['snap', '1']],
#  [['sending', '0']],
#  [['transmission', '1'], ['transmittal', '0'], ['transmitting', '0']],
#  [['forwarding', '1']],
#  [['referral', '0']],
#  [['remission', '1'], ['remitment', '0'], ['remit', '0']],
#  [['mailing', '0'], ['posting', '0']],
#  [['wheeling', '0'], ['rolling', '0']],
#  [['shooting', '0'], ['shot', '0']],
#  [['shoot', '0']],
#  [['countershot', '0']],
#  [['discharge', '0'], ['firing', '2'], ['firing_off', '0']],
#  [['gun', '0']],
#  [['fire_control', '0']],
#  [['gunfire', '0'], ['gunshot', '0']],
#  [['enfilade', '0'], ['enfilade_fire', '0']],
#  [['snipe', '0']],
#  [['headshot', '0']],
#  [['skeet', '0'], ['skeet_shooting', '0'], ['trapshooting', '0']],
#  [['shellfire', '0']],
#  [['gunfight', '0'], ['gunplay', '0'], ['shootout', '0']],
#  [['potshot', '0']],
#  [['contact', '0'], ['physical_contact', '0']],
#  [['rub', '0'], ['wipe', '0']],
#  [['scuff', '0']],
#  [['tap', '0'], ['pat', '0'], ['dab', '0']],
#  [['hit', '0'], ['hitting', '0'], ['striking', '0']],
#  [['contusion', '0']],
#  [['crash', '0'], ['smash', '0']],
#  [['impingement', '1'], ['impaction', '0']],
#  [['batting', '0']],
#  [['fielding', '0']],
#  [['catching', '0']],
#  [['golfing', '0']],
#  [['pitching', '0']],
#  [['base_on_balls', '0'], ['walk', '1'], ['pass', '4']],
#  [['best', '0']],
#  [['worst', '0']],
#  [['fair_ball', '0']],
#  [['foul_ball', '0']],
#  [['snick', '1']],
#  [['bunt', '0']],
#  [['fly', '0'], ['fly_ball', '0']],
#  [['blast', '0']],
#  [['pop_fly', '0'], ['pop-fly', '0'], ['pop-up', '0']],
#  [['grounder', '0'],
#   ['ground_ball', '0'],
#   ['groundball', '0'],
#   ['hopper', '0']],
#  [['chop', '1'], ['chopper', '0']],
#  [['roller', '0']],
#  [['out', '0']],
#  [['force_out', '0'], ['force-out', '0'], ['force_play', '0'], ['force', '0']],
#  [['putout', '0']],
#  [['strikeout', '0']],
#  [['whiff', '0']],
#  [["fielder's_choice", '0']],
#  [['sacrifice', '2']],
#  [['sacrifice_fly', '0']],
#  [['base_hit', '0'], ['safety', '0']],
#  [['daisy_cutter', '0']],
#  [['header', '0']],
#  [['liner', '0'], ['line_drive', '0']],
#  [['scorcher', '0'], ['screamer', '0']],
#  [['line-drive_single', '0'], ['line_single', '0']],
#  [['line-drive_double', '0'], ['line_double', '0']],
#  [['line-drive_triple', '0'], ['line_triple', '0']],
#  [['plunk', '0'], ['plunker', '0']],
#  [['homer', '0'], ['home_run', '0']],
#  [['solo_homer', '0'], ['solo_blast', '0']],
#  [['single', '0'], ['bingle', '0']],
#  [['double', '0'],
#   ['two-base_hit', '0'],
#   ['two-bagger', '0'],
#   ['two-baser', '0']],
#  [['triple', '0'], ['three-base_hit', '0'], ['three-bagger', '0']],
#  [['backhander', '0']],
#  [['clip', '1']],
#  [['knock', '0'], ['belt', '0'], ['rap', '0'], ['whack', '0'], ['whang', '0']],
#  [['thwack', '0']],
#  [['smack', '0'], ['smacking', '0'], ['slap', '0']],
#  [['smacker', '1']],
#  [['knockdown', '0']],
#  [['knockout', '0'], ['KO', '0'], ['kayo', '0']],
#  [['technical_knockout', '0'], ['TKO', '0']],
#  [['swat', '0']],
#  [['spank', '0']],
#  [['whip', '0'], ['lash', '0'], ['whiplash', '0']],
#  [['punch', '0'],
#   ['clout', '0'],
#   ['poke', '0'],
#   ['lick', '1'],
#   ['biff', '0'],
#   ['slug', '0']],
#  [['box', '0']],
#  [['dig', '2'], ['jab', '2']],
#  [['counterpunch', '0'], ['parry', '0'], ['counter', '0']],
#  [['haymaker', '0'],
#   ['knockout_punch', '0'],
#   ['KO_punch', '0'],
#   ['Sunday_punch', '0']],
#  [['hook', '0']],
#  [['jab', '0']],
#  [['rabbit_punch', '0']],
#  [['sucker_punch', '0']],
#  [['roundhouse', '0']],
#  [['kick', '0'], ['boot', '0'], ['kicking', '0']],
#  [['goal-kick', '0']],
#  [['goal-kick', '1']],
#  [['punt', '0'], ['punting', '0']],
#  [['place_kick', '0'], ['place-kicking', '0']],
#  [['free_kick', '0']],
#  [['corner_kick', '0']],
#  [['dropkick', '0']],
#  [['kiss', '1']],
#  [['kiss', '0'], ['buss', '0'], ['osculation', '0']],
#  [['laying_on', '0']],
#  [['smack', '1'], ['smooch', '0']],
#  [['smacker', '0']],
#  [['soul_kiss', '0'], ['deep_kiss', '0'], ['French_kiss', '0']],
#  [['catch', '0'], ['grab', '0'], ['snatch', '0'], ['snap', '0']],
#  [['fair_catch', '0']],
#  [['interception', '1']],
#  [['reception', '3']],
#  [['rebound', '0']],
#  [['shoestring_catch', '0']],
#  [['mesh', '0'], ['meshing', '0'], ['interlock', '0'], ['interlocking', '0']],
#  [['handling', '1'], ['manipulation', '1']],
#  [['fingering', '0']],
#  [['grope', '0']],
#  [['audit', '0']],
#  [['autopsy', '0'],
#   ['necropsy', '0'],
#   ['postmortem', '0'],
#   ['post-mortem', '0'],
#   ['PM', '0'],
#   ['postmortem_examination', '0'],
#   ['post-mortem_examination', '0']],
#  [['check-in', '0']],
#  [['check', '5'], ['checkout', '0'], ['check-out_procedure', '0']],
#  [['spot_check', '0']],
#  [['checkup', '0'],
#   ['medical_checkup', '0'],
#   ['medical_examination', '0'],
#   ['medical_exam', '0'],
#   ['medical', '0'],
#   ['health_check', '0']],
#  [['comparison', '0'], ['comparing', '0']],
#  [['fine-tooth_comb', '0'], ['fine-toothed_comb', '0']],
#  [['follow-up', '0'],
#   ['followup', '0'],
#   ['reexamination', '0'],
#   ['review', '0']],
#  [['going-over', '0']],
#  [['once-over', '0'], ['look-over', '0']],
#  [['ophthalmoscopy', '0']],
#  [['palpation', '0'], ['tactual_exploration', '0']],
#  [['ballottement', '0']],
#  [['tickle', '0'], ['tickling', '0'], ['titillation', '0']],
#  [['stroke', '1'], ['stroking', '0']],
#  [['caress', '0']],
#  [['tag', '0']],
#  [['joining', '0'], ['connection', '0'], ['connexion', '0']],
#  [['hit', '5']],
#  [['interconnection', '0']],
#  [['intersection', '0']],
#  [['approximation', '0'], ['bringing_close_together', '0']],
#  [['concatenation', '0']],
#  [['convergence', '1'], ['converging', '0'], ['convergency', '0']],
#  [['merging', '2'], ['meeting', '2'], ['coming_together', '2']],
#  [['concourse', '0'], ['confluence', '2']],
#  [['encounter', '1'], ['coming_upon', '0']],
#  [['articulation', '0']],
#  [['junction', '0'], ['adjunction', '0']],
#  [['fastening', '0'], ['attachment', '0']],
#  [['loosening', '0'], ['laxation', '0']],
#  [['tightening', '0']],
#  [['ligation', '0']],
#  [['tubal_ligation', '0']],
#  [['bonding', '0'], ['soldering', '0']],
#  [['doweling', '0']],
#  [['grounding', '0'], ['earthing', '0']],
#  [['linkage', '0']],
#  [['tying', '0'], ['ligature', '0']],
#  [['untying', '0'], ['undoing', '1'], ['unfastening', '0']],
#  [['welding', '0']],
#  [['butt_welding', '0'], ['butt-welding', '0']],
#  [['spot_welding', '0'], ['spot-welding', '0']],
#  [['flare', '0']],
#  [['Texas_leaguer', '0']],
#  [['flash_welding', '0'], ['flash_butt_welding', '0']],
#  [['lick', '0'], ['lap', '0']],
#  [['grazing', '0'], ['shaving', '1'], ['skimming', '2']],
#  [['tracing', '1']],
#  [['detection', '0'],
#   ['catching', '1'],
#   ['espial', '0'],
#   ['spying', '2'],
#   ['spotting', '0']],
#  [['self-discovery', '0']],
#  [['breakthrough', '2']],
#  [['determination', '0'], ['finding', '0']],
#  [['rediscovery', '0']],
#  [['designation', '1'], ['identification', '0']],
#  [['Bertillon_system', '0']],
#  [['fingerprinting', '0']],
#  [['genetic_profiling', '0'], ['genetic_fingerprinting', '0']],
#  [['diagnosis', '0'], ['diagnosing', '0']],
#  [['blood_typing', '0']],
#  [['medical_diagnosis', '0']],
#  [['prenatal_diagnosis', '0']],
#  [['differential_diagnosis', '0']],
#  [['prognosis', '0'], ['prospect', '0'], ['medical_prognosis', '0']],
#  [['resolution', '1'], ['solving', '0']],
#  [['validation', '0'], ['proof', '0'], ['substantiation', '0']],
#  [['authentication', '0'], ['certification', '1']],
#  [['documentation', '0'], ['support', '2']],
#  [['monetization', '1'], ['monetisation', '1']],
#  [['probate', '0']],
#  [['demonetization', '0'], ['demonetisation', '0']],
#  [['falsification', '1'],
#   ['falsifying', '0'],
#   ['disproof', '0'],
#   ['refutation', '0'],
#   ['refutal', '0']],
#  [['localization', '0'],
#   ['localisation', '0'],
#   ['location', '1'],
#   ['locating', '1'],
#   ['fix', '2']],
#  [['echolocation', '0'], ['echo_sounding', '0']],
#  [['predetermination', '0']],
#  [['rectification', '1']],
#  [['redetermination', '0']],
#  [['trigger', '0'], ['induction', '3'], ['initiation', '2']],
#  [['fomentation', '0'], ['instigation', '0']],
#  [['compulsion', '0'], ['coercion', '0']],
#  [['influence', '0']],
#  [['cross-pollination', '0']],
#  [['exposure', '6']],
#  [['overexposure', '1']],
#  [['underexposure', '1']],
#  [['impingement', '0'], ['encroachment', '2'], ['impact', '0']],
#  [['manipulation', '0'], ['use', '2']],
#  [['mind_game', '0']],
#  [['autosuggestion', '0'], ['auto-suggestion', '0'], ['self-suggestion', '0']],
#  [['hypnotism', '0'], ['mesmerism', '0'], ['suggestion', '2']],
#  [['inducement', '0'], ['inducing', '0']],
#  [['corruption', '1']],
#  [['enticement', '0'], ['temptation', '0']],
#  [['blandishment', '0'], ['wheedling', '0']],
#  [['ingratiation', '0'], ['insinuation', '0']],
#  [['leading_astray', '0'], ['leading_off', '0']],
#  [['seduction', '0']],
#  [['seduction', '1'], ['conquest', '2']],
#  [['sexual_conquest', '0'], ['score', '1']],
#  [['cuckoldry', '0']],
#  [['solicitation', '1'], ['allurement', '0']],
#  [['choice', '0'], ['selection', '0'], ['option', '0'], ['pick', '0']],
#  [['casting', '3']],
#  [['coloration', '0'], ['colouration', '0']],
#  [['sampling', '0']],
#  [['random_sampling', '0']],
#  [['lucky_dip', '1']],
#  [['stratified_sampling', '0'],
#   ['representative_sampling', '0'],
#   ['proportional_sampling', '0']],
#  [['decision', '0'], ['determination', '1'], ['conclusion', '1']],
#  [['volition', '0'], ['willing', '0']],
#  [['intention', '0']],
#  [['about-face', '1'],
#   ['volte-face', '0'],
#   ['reversal', '5'],
#   ['policy_change', '0']],
#  [['adulteration', '0']],
#  [['appointment', '0'],
#   ['assignment', '1'],
#   ['designation', '0'],
#   ['naming', '0']],
#  [['nomination', '0']],
#  [['assignment', '2'], ['assigning', '0']],
#  [['allocation', '1'], ['storage_allocation', '0']],
#  [['call', '0']],
#  [['co-option', '1'], ['co-optation', '1']],
#  [['delegacy', '0']],
#  [['ordination', '0'], ['ordinance', '0']],
#  [['recognition', '0']],
#  [['laying_on_of_hands', '0']],
#  [['move', '0']],
#  [['move', '2']],
#  [['chess_move', '0']],
#  [['castle', '0'], ['castling', '0']],
#  [['capture', '2']],
#  [['en_passant', '0']],
#  [['exchange', '4']],
#  [['exchange', '5']],
#  [['check', '4']],
#  [['discovered_check', '0']],
#  [['checkmate', '0'], ['mate', '0']],
#  [['gambit', '0']],
#  [['demarche', '0']],
#  [['maneuver', '0'],
#   ['manoeuvre', '0'],
#   ['tactical_maneuver', '0'],
#   ['tactical_manoeuvre', '0']],
#  [['parking', '0']],
#  [['move', '1'], ['relocation', '0']],
#  [['flit', '1']],
#  [['downshift', '0']],
#  [['downshift', '1']],
#  [['bank', '0']],
#  [['vertical_bank', '0']],
#  [['chandelle', '0']],
#  [['loop', '0'], ['loop-the-loop', '0']],
#  [['inside_loop', '0']],
#  [['outside_loop', '0']],
#  [['roll', '0']],
#  [['barrel_roll', '0']],
#  [['snap_roll', '0']],
#  [['slip', '0'], ['sideslip', '1']],
#  [['flight_maneuver', '0'], ['airplane_maneuver', '0']],
#  [['straight-arm', '0']],
#  [['device', '0'], ['gimmick', '0'], ['twist', '1']],
#  [['mnemonic', '0']],
#  [['trick', '5'], ['fast_one', '0']],
#  [['shtik', '2'], ['schtik', '2'], ['shtick', '2'], ['schtick', '2']],
#  [['feint', '0']],
#  [['juke', '0'], ['fake', '0']],
#  [['footwork', '1']],
#  [['ploy', '0'], ['gambit', '1'], ['stratagem', '0']],
#  [['ruse', '0'], ['artifice', '0']],
#  [['means', '0'], ['agency', '0'], ['way', '1']],
#  [['dint', '0']],
#  [['escape', '4']],
#  [['fast_track', '0']],
#  [['instrument', '0'], ['tool', '0']],
#  [['road', '0']],
#  [['royal_road', '0']],
#  [['stepping_stone', '0']],
#  [['measure', '1'], ['step', '2']],
#  [['countermeasure', '0']],
#  [['bear_hug', '1']],
#  [['proxy_fight', '0']],
#  [['leveraged_buyout', '0']],
#  [['bust-up_takeover', '0']],
#  [['shark_repellent', '0'], ['porcupine_provision', '0']],
#  [['golden_parachute', '0']],
#  [['greenmail', '0']],
#  [['pac-man_strategy', '0']],
#  [['poison_pill', '0']],
#  [['suicide_pill', '0']],
#  [['safe_harbor', '0']],
#  [['scorched-earth_policy', '0']],
#  [['diagnostic_procedure', '0'], ['diagnostic_technique', '0']],
#  [['expedient', '0']],
#  [['backstop', '0']],
#  [['emergency_procedure', '0']],
#  [['experimental_procedure', '0']],
#  [['double-blind_procedure', '0'],
#   ['double-blind_experiment', '0'],
#   ['double-blind_study', '0']],
#  [['makeshift', '0'], ['stopgap', '0'], ['make-do', '0']],
#  [['crutch', '0']],
#  [['improvisation', '0'], ['temporary_expedient', '0']],
#  [['pis_aller', '0'], ['last_resort', '0']],
#  [['desperate_measure', '0']],
#  [['open_sesame', '0']],
#  [['salvation', '1']],
#  [['tooth', '0']],
#  [['voice', '0']],
#  [['wings', '0']],
#  [['casting_lots', '0'], ['drawing_lots', '0'], ['sortition', '0']],
#  [['resolution', '0']],
#  [['adoption', '0'],
#   ['acceptance', '0'],
#   ['acceptation', '0'],
#   ['espousal', '0']],
#  [['embrace', '1'], ['bosom', '0']],
#  [['election', '0']],
#  [['co-option', '0'], ['co-optation', '0']],
#  [['reelection', '0']],
#  [['plebiscite', '0']],
#  [['referendum', '0']],
#  [['election', '1']],
#  [['vote', '1']],
#  [['general_election', '0']],
#  [['primary', '0'], ['primary_election', '0']],
#  [['direct_primary', '0']],
#  [['closed_primary', '0']],
#  [['open_primary', '0']],
#  [['by-election', '0'], ['bye-election', '0']],
#  [['runoff', '0']],
#  [['vote', '0'], ['ballot', '0'], ['voting', '0'], ['balloting', '0']],
#  [['block_vote', '0']],
#  [['cumulative_vote', '0']],
#  [['secret_ballot', '0']],
#  [['split_ticket', '0']],
#  [['straight_ticket', '0']],
#  [['multiple_voting', '0']],
#  [['casting_vote', '0']],
#  [['reconciliation', '0'], ['balancing', '0']],
#  [['equation', '0'], ['equating', '0']],
#  [['breech_delivery', '0'],
#   ['breech_birth', '0'],
#   ['breech_presentation', '0']],
#  [['frank_breech', '0'], ['frank_breech_delivery', '0']],
#  [['cesarean_delivery', '0'],
#   ['caesarean_delivery', '0'],
#   ['caesarian_delivery', '0'],
#   ['cesarean_section', '0'],
#   ['cesarian_section', '0'],
#   ['caesarean_section', '0'],
#   ['caesarian_section', '0'],
#   ['C-section', '0'],
#   ['cesarean', '0'],
#   ['cesarian', '0'],
#   ['caesarean', '0'],
#   ['caesarian', '0'],
#   ['abdominal_delivery', '0']],
#  [['forceps_delivery', '0']],
#  [['midwifery', '0']],
#  [['score', '0']],
#  [['bowling_score', '0']],
#  [["bull's_eye", '0']],
#  [['goal', '0']],
#  [['own_goal', '0']],
#  [['strike', '1'], ['ten-strike', '0']],
#  [['spare', '0']],
#  [['open_frame', '0'], ['break', '6']],
#  [['audible', '0']],
#  [['football_score', '0']],
#  [['touchback', '0']],
#  [['safety', '1']],
#  [['touchdown', '0']],
#  [['field_goal', '0']],
#  [['conversion', '2']],
#  [['point_after', '0'], ['point_after_touchdown', '0'], ['extra_point', '0']],
#  [['baseball_score', '0']],
#  [['run', '1'], ['tally', '1']],
#  [['earned_run', '0']],
#  [['unearned_run', '0']],
#  [['run_batted_in', '0'], ['rbi', '0']],
#  [['basketball_score', '0']],
#  [['basket', '0'], ['field_goal', '1']],
#  [['hat_trick', '0']],
#  [['solution', '0']],
#  [['Russian_roulette', '0']],
#  [['change', '0']],
#  [['filtration', '0']],
#  [['percolation', '1']],
#  [['reduction', '2'], ['simplification', '2']],
#  [['schematization', '1'], ['schematisation', '1']],
#  [['economy', '0'], ['saving', '0']],
#  [['retrenchment', '0'], ['curtailment', '1'], ['downsizing', '0']],
#  [['economy_of_scale', '0']],
#  [['accommodation', '1']],
#  [['adaptation', '1']],
#  [['dark_adaptation', '0']],
#  [['light_adaptation', '0']],
#  [['take-up', '0']],
#  [['readjustment', '0']],
#  [['domestication', '0']],
#  [['decimalization', '0'], ['decimalisation', '0']],
#  [['metrification', '0'], ['metrication', '0']],
#  [['habituation', '0']],
#  [['variation', '0'], ['variance', '0']],
#  [['variation', '1']],
#  [['turning', '1']],
#  [['diversification', '0'], ['variegation', '0']],
#  [['flux', '0']],
#  [['switch', '0'], ['switching', '0'], ['shift', '1']],
#  [['switcheroo', '0']],
#  [['substitution', '0'], ['exchange', '1'], ['commutation', '2']],
#  [['novation', '0']],
#  [['pitching_change', '0']],
#  [['superannuation', '0']],
#  [['supersedure', '0'], ['supersession', '0']],
#  [['supplanting', '0'], ['displacement', '0']],
#  [['replacement', '0'], ['replacing', '0']],
#  [['subrogation', '0']],
#  [['weaning', '0'], ['ablactation', '0']],
#  [['promotion', '0']],
#  [['preferment', '0']],
#  [['demotion', '0']],
#  [['investment', '2'], ['investiture', '0']],
#  [['change_of_state', '0']],
#  [['alteration', '1'], ['modification', '0'], ['adjustment', '0']],
#  [['distraction', '2'], ['misdirection', '1']],
#  [['aeration', '0']],
#  [['modulation', '0']],
#  [['qualification', '0']],
#  [['reorganization', '1']],
#  [['passage', '4'], ['transition', '0']],
#  [['fossilization', '0'], ['fossilisation', '0']],
#  [['segue', '0']],
#  [['meddling', '0'], ['tampering', '0']],
#  [['transfer', '3'], ['transference', '1']],
#  [['prohibition', '0'], ['inhibition', '1'], ['forbiddance', '0']],
#  [['resistance', '2'], ['opposition', '1']],
#  [['lockout', '0']],
#  [['reaction', '1']],
#  [['backlash', '0']],
#  [['whitelash', '0'], ['white_backlash', '0']],
#  [['rejection', '0']],
#  [['brush-off', '0']],
#  [['avoidance', '0'],
#   ['turning_away', '0'],
#   ['shunning', '0'],
#   ['dodging', '1']],
#  [['aversion', '0'], ['averting', '1']],
#  [['escape', '3']],
#  [['near_thing', '0']],
#  [['abandonment', '3'], ['forsaking', '0'], ['desertion', '1']],
#  [['exposure', '1']],
#  [['apostasy', '0'], ['tergiversation', '1']],
#  [['bolt', '0']],
#  [['renunciation', '0'], ['forgoing', '0'], ['forswearing', '0']],
#  [['nonacceptance', '0'], ['turndown', '0']],
#  [['forsaking', '1'], ['giving_up', '0']],
#  [['abnegation', '0'],
#   ['self-abnegation', '0'],
#   ['denial', '1'],
#   ['self-denial', '1'],
#   ['self-renunciation', '0']],
#  [['forfeit', '0'], ['forfeiture', '0'], ['sacrifice', '1']],
#  [['boycott', '0']],
#  [['banishment', '0'], ['proscription', '0']],
#  [['anathematization', '0'], ['anathematisation', '0']],
#  [['disbarment', '0']],
#  [['ejection', '0'],
#   ['exclusion', '1'],
#   ['expulsion', '1'],
#   ['riddance', '0']],
#  [['deportation', '1']],
#  [['ostracism', '0']],
#  [['barring', '0'], ['blackball', '0']],
#  [['exile', '0'],
#   ['deportation', '0'],
#   ['expatriation', '0'],
#   ['transportation', '2']],
#  [['Babylonian_Captivity', '0']],
#  [['excommunication', '0'], ['excision', '2']],
#  [['relegation', '1']],
#  [['rustication', '1']],
#  [['ouster', '0'], ['ousting', '0']],
#  [['deposition', '0'], ['dethronement', '0']],
#  [['suspension', '1'], ['temporary_removal', '0']],
#  [['rustication', '3']],
#  [['displacement', '1']],
#  [['veto', '0']],
#  [['pocket_veto', '0']],
#  [['write-in', '0']],
#  [['termination', '0'], ['ending', '0'], ['conclusion', '0']],
#  [['finish', '0'], ['finishing', '0']],
#  [['finale', '0'], ['close', '0'], ['closing_curtain', '0'], ['finis', '0']],
#  [['release', '6'], ['tone_ending', '0']],
#  [['completion', '0'],
#   ['culmination', '0'],
#   ['closing', '2'],
#   ['windup', '0'],
#   ['mop_up', '0']],
#  [['finalization', '0'], ['finalisation', '0']],
#  [['follow-through', '0']],
#  [['follow-through', '1']],
#  [['graduation', '1']],
#  [['retirement', '0']],
#  [['hibernation', '0']],
#  [['rustication', '0']],
#  [['swan_song', '0'], ['last_hurrah', '0']],
#  [['relinquishment', '0'], ['relinquishing', '0']],
#  [['cession', '0'], ['ceding', '0']],
#  [['handover', '0']],
#  [['surrender', '1']],
#  [['extradition', '0']],
#  [['release', '5'], ['waiver', '0'], ['discharge', '2']],
#  [['exemption', '0'], ['immunity', '0'], ['granting_immunity', '0']],
#  [['fix', '1']],
#  [['official_immunity', '0']],
#  [['sovereign_immunity', '0']],
#  [['transactional_immunity', '0']],
#  [['use_immunity', '0'], ['testimonial_immunity', '0']],
#  [['dissolution', '0'], ['breakup', '0']],
#  [['splitsville', '0']],
#  [['overthrow', '1']],
#  [['subversion', '1'], ['subversive_activity', '0']],
#  [['adjournment', '0'], ['dissolution', '1']],
#  [['dismissal', '0'],
#   ['dismission', '0'],
#   ['discharge', '1'],
#   ['firing', '1'],
#   ['liberation', '1'],
#   ['release', '2'],
#   ['sack', '0'],
#   ['sacking', '0']],
#  [['conge', '1'], ['congee', '1']],
#  [['removal', '2']],
#  [['purge', '2']],
#  [['destruction', '0'], ['devastation', '0']],
#  ...]
